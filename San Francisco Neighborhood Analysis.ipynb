# %% [markdown]
# # FourSquare API-San Francisco City Neighborhood Analysis with Python and Folium

# %%
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation


# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

#!conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Folium installed
# Libraries imported.

# %%
from config_foursquare import CLIENT_ID,CLIENT_SECRET
CLIENT_ID =CLIENT_ID
CLIENT_SECRET = CLIENT_SECRET 
VERSION="20180731"
LIMIT=30


import warnings #Warning module to filter any future warnings
warnings.filterwarnings('ignore')

# %%
address = '501 Geary St, San Francisco, CA 94102'#The Marker SFO
geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 37.7866329 -122.41195210013

# %%
search_query = 'Italian'
radius = 500
print(search_query + ' .... OK!')
# Out:
# Italian .... OK!

# %%
url=f"http://api.foursquare.com/v2/venues/search?client_id={CLIENT_ID}&client_secret={CLIENT_SECRET}&v={VERSION}&ll={latitude},{longitude}&query={search_query}&radius={radius}&limit=10"
url
# Out:
# 'http://api.foursquare.com/v2/venues/search?client_id=L0XUK3OF0DEMWCIMYXLNQEDWMM1GIBC43PQCFYYID2XGX4WV&client_secret=FYVOYA1ZZ3YQ320RWOU5XCVD1Y3TA1BCTGIW2OS5ZJTG4CKH&v=20180731&ll=37.7866329,-122.41195210013&query=Italian&radius=500&limit=10'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5b6385d74c1f677b0b6d06c6'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'primary': True,
#       'shortName': 'Italian'}],
#     'hasPerk': False,
#     'id': '4a19721ef964a520197a1fe3',
#     'location': {'address': '624 Post St',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'country': 'United States',
#      'crossStreet': 'btw Taylor St & Trader Vic Aly',
#      'distance': 146,
#      'formattedAddress': ['624 Post St (btw Taylor St & Trader Vic Aly)',
#       'San Francisco, CA 94109',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.78792121397233,
#        'lng': -122.41226661901916}],
#      'lat': 37.78792121397233,
#      'lng': -122.41226661901916,
#      'postalCode': '94109',
#      'state': 'CA'},
#     'name': 'Fino Restaurant',
#     'referralId': 'v-1533248983'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'primary': True,
#       'shortName': 'Italian'}],
#     'hasPerk': False,
#     'id': '4af6357bf964a520400222e3',
#     'location': {'address': '835 Hyde St',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'country': 'United States',
#      'distance': 495,
#      'formattedAddress': ['835 Hyde St',
#       'San Francisco, CA 94109',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.78871293006333,
#        'lng': -122.41692590724674}],
#      'lat': 37.78871293006333,
#      'lng': -122.41692590724674,
#      'postalCode': '94109',
#      'state': 'CA'},
#     'name': 'Colombini Bistro',
#     'referralId': 'v-1533248983'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'primary': True,
#       'shortName': 'Food'}],
#     'hasPerk': False,
#     'id': '4f44ee5819836ed001978c46',
#     'location': {'address': '870 Market St',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'country': 'United States',
#      'distance': 486,
#      'formattedAddress': ['870 Market St',
#       'San Francisco, CA 94102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.785415,
#        'lng': -122.406645}],
#      'lat': 37.785415,
#      'lng': -122.406645,
#      'postalCode': '94102',
#      'state': 'CA'},
#     'name': 'Panoroma Italiano',
#     'referralId': 'v-1533248983'}]}}

# %%
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...    False
# 1  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...    False
# 2  [{'id': '4d4b7105d754a06374d81259', 'name': 'F...    False
#
#                          id location.address location.cc  location.city  \
# 0  4a19721ef964a520197a1fe3      624 Post St          US  San Francisco
# 1  4af6357bf964a520400222e3      835 Hyde St          US  San Francisco
# 2  4f44ee5819836ed001978c46    870 Market St          US  San Francisco
#
#   location.country            location.crossStreet  location.distance  \
# 0    United States  btw Taylor St & Trader Vic Aly                146
# 1    United States                             NaN                495
# 2    United States                             NaN                486
#
#                            location.formattedAddress  \
# 0  [624 Post St (btw Taylor St & Trader Vic Aly),...
# 1  [835 Hyde St, San Francisco, CA 94109, United ...
# 2  [870 Market St, San Francisco, CA 94102, Unite...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 37.78792121397233...     37.787921
# 1  [{'label': 'display', 'lat': 37.78871293006333...     37.788713
# 2  [{'label': 'display', 'lat': 37.785415, 'lng':...     37.785415
#
#    location.lng location.postalCode location.state               name  \
# 0   -122.412267               94109             CA    Fino Restaurant
# 1   -122.416926               94109             CA   Colombini Bistro
# 2   -122.406645               94102             CA  Panoroma Italiano
#
#      referralId
# 0  v-1533248983
# 1  v-1533248983
# 2  v-1533248983

# %%
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
print(filtered_columns)
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
# ['name', 'categories', 'location.address', 'location.cc', 'location.city', 'location.country', 'location.crossStreet', 'location.distance', 'location.formattedAddress', 'location.labeledLatLngs', 'location.lat', 'location.lng', 'location.postalCode', 'location.state', 'id']
#                 name          categories        address  cc           city  \
# 0    Fino Restaurant  Italian Restaurant    624 Post St  US  San Francisco
# 1   Colombini Bistro  Italian Restaurant    835 Hyde St  US  San Francisco
# 2  Panoroma Italiano                Food  870 Market St  US  San Francisco
#
#          country                     crossStreet  distance  \
# 0  United States  btw Taylor St & Trader Vic Aly       146
# 1  United States                             NaN       495
# 2  United States                             NaN       486
#
#                                     formattedAddress  \
# 0  [624 Post St (btw Taylor St & Trader Vic Aly),...
# 1  [835 Hyde St, San Francisco, CA 94109, United ...
# 2  [870 Market St, San Francisco, CA 94102, Unite...
#
#                                       labeledLatLngs        lat         lng  \
# 0  [{'label': 'display', 'lat': 37.78792121397233...  37.787921 -122.412267
# 1  [{'label': 'display', 'lat': 37.78871293006333...  37.788713 -122.416926
# 2  [{'label': 'display', 'lat': 37.785415, 'lng':...  37.785415 -122.406645
#
#   postalCode state                        id
# 0      94109    CA  4a19721ef964a520197a1fe3
# 1      94109    CA  4af6357bf964a520400222e3
# 2      94102    CA  4f44ee5819836ed001978c46

# %%
dataframe_filtered.name
# Out:
# 0      Fino Restaurant
# 1     Colombini Bistro
# 2    Panoroma Italiano
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='The Marker',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng ,label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.name):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
venue_id='4a19721ef964a520197a1fe3'
url_ven=f"https://api.foursquare.com/v2/venues/{venue_id}?&client_id={CLIENT_ID}&client_secret={CLIENT_SECRET}&v={VERSION}"

# %%
result_ven=requests.get(url_ven).json()
result_ven
# Out:
# {'meta': {'code': 504,
#   'errorDetail': 'Foursquare servers are experiencing problems. Please retry and check status.foursquare.com for updates.',
#   'errorType': 'server_error'},
#  'response': {}}

# %%
result_ven['response']['venue'].keys()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-1e8ca2680cd3> in <module>()
# ----> 1 result_ven['response']['venue'].keys()
#
# KeyError: 'venue'

# %%
try:
    print(result_ven['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %%
venueid='4af6357bf964a520400222e3'
url_ven=f"https://api.foursquare.com/v2/venues/{venueid}?&client_id={CLIENT_ID}&client_secret={CLIENT_SECRET}&v={VERSION}"
result_ven=requests.get(url_ven).json()
try:
    print(result_ven['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %%
#tips_count=result_ven['response']['venue']['tips']['count']
result_ven['response']
# Out:
# {}

# %%
venueid='4f44ee5819836ed001978c46'
url_ven=f"https://api.foursquare.com/v2/venues/{venueid}?&client_id={CLIENT_ID}&client_secret={CLIENT_SECRET}&v={VERSION}"
result_ven=requests.get(url_ven).json()
try:
    print(result_ven['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %%
result_ven['response']['venue']['tips']['count']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-363c9a846457> in <module>()
# ----> 1 result_ven['response']['venue']['tips']['count']
#
# KeyError: 'venue'

# %% [markdown]
# ## Get the venue's tips
# https://api.foursquare.com/v2/venues/VENUE_ID/tips?client_id=CLIENT_ID&client_secret=CLIENT_SECRET&v=VERSION&limit=LIMIT

# %%
VENUE_ID='4a19721ef964a520197a1fe3'
url_tips=f"https://api.foursquare.com/v2/venues/{VENUE_ID}/tips?client_id={CLIENT_ID}&client_secret={CLIENT_SECRET}&v={VERSION}&limit={LIMIT}"

# %%
result_tips=requests.get(url_tips).json()

# %%
result_tips['response']['tips']['items'][0]['text']
# Out:
# 'Delicious and authentic! I loved their risotto special with the HUGE scallops. Our table ordered many dishes and desserts and they all stood out.'

# %%
tips_df=json_normalize(result_tips['response']['tips']['items'][0])

# %%
tips_df
# Out:
#    agreeCount authorInteractionType  \
# 0           1                 liked
#
#                                         canonicalUrl   createdAt  \
# 0  https://foursquare.com/item/5b0f202fcf72a0002c...  1527717935
#
#    disagreeCount                        id lang  lastUpvoteTimestamp  \
# 0              0  5b0f202fcf72a0002cf16c2d   en           1530744170
#
#           lastVoteText  likes.count  \
# 0  Upvoted 4 weeks ago            0
#
#                          ...                          \
# 0                        ...
#
#                                             photourl  \
# 0  https://igx.4sqi.net/img/general/original/7835...
#
#                                                 text  todo.count  type  \
# 0  Delicious and authentic! I loved their risotto...           0  user
#
#   user.firstName user.gender  user.id user.lastName  \
# 0          Paige      female  7835045             C
#
#                 user.photo.prefix  \
# 0  https://igx.4sqi.net/img/user/
#
#                                    user.photo.suffix
# 0  /7835045_vzeT9M7E_W9mOqaLB2Kjg0RdSk9ZaZ3qumWd8...
#
# [1 rows x 31 columns]

# %%
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id', 'user.firstName', 'user.lastName', 'user.gender', 'user.id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display tips
tips_filtered
# Out:
#                                                 text  agreeCount  \
# 0  Delicious and authentic! I loved their risotto...           1
#
#    disagreeCount                        id user.firstName user.lastName  \
# 0              0  5b0f202fcf72a0002cf16c2d          Paige             C
#
#   user.gender  user.id
# 0      female  7835045

# %%
result_tips['response']['tips']['items'][0]
# Out:
# {'agreeCount': 1,
#  'authorInteractionType': 'liked',
#  'canonicalUrl': 'https://foursquare.com/item/5b0f202fcf72a0002cf16c2d',
#  'createdAt': 1527717935,
#  'disagreeCount': 0,
#  'id': '5b0f202fcf72a0002cf16c2d',
#  'lang': 'en',
#  'lastUpvoteTimestamp': 1530744170,
#  'lastVoteText': 'Upvoted 4 weeks ago',
#  'likes': {'count': 0, 'groups': []},
#  'logView': True,
#  'photo': {'createdAt': 1527717937,
#   'height': 1920,
#   'id': '5b0f2031b9b37b002cda25de',
#   'prefix': 'https://igx.4sqi.net/img/general/',
#   'source': {'name': 'Foursquare for iOS',
#    'url': 'https://foursquare.com/download/#/iphone'},
#   'suffix': '/7835045_ZBAbXkjiSO-GfaOsZLWOHix3QJK9WaCBomOpKJz0aaM.jpg',
#   'visibility': 'public',
#   'width': 1440},
#  'photourl': 'https://igx.4sqi.net/img/general/original/7835045_ZBAbXkjiSO-GfaOsZLWOHix3QJK9WaCBomOpKJz0aaM.jpg',
#  'text': 'Delicious and authentic! I loved their risotto special with the HUGE scallops. Our table ordered many dishes and desserts and they all stood out.',
#  'todo': {'count': 0},
#  'type': 'user',
#  'user': {'firstName': 'Paige',
#   'gender': 'female',
#   'id': '7835045',
#   'lastName': 'C',
#   'photo': {'prefix': 'https://igx.4sqi.net/img/user/',
#    'suffix': '/7835045_vzeT9M7E_W9mOqaLB2Kjg0RdSk9ZaZ3qumWd83vX699ukd2xQKig6s29t8WuzPpeBW54z34H4.jpg'}}}

# %% [markdown]
# # Search a Foursquare User
# https://api.foursquare.com/v2/users/USER_ID?client_id=CLIENT_ID&client_secret=CLIENT_SECRET&v=VERSION

# %%
USER_ID="7835045"
url_user=f"https://api.foursquare.com/v2/users/{USER_ID}?client_id={CLIENT_ID}&client_secret={CLIENT_SECRET}&v={VERSION}"

# %%
result_user=requests.get(url_user).json()
user_data=result_user['response']['user']
result_user['response']['user'].keys()
# Out:
# dict_keys(['id', 'firstName', 'lastName', 'gender', 'canonicalUrl', 'photo', 'friends', 'tips', 'homeCity', 'bio', 'contact', 'superuser', 'photos', 'type', 'mayorships', 'checkins', 'lists', 'lenses'])

# %%
user_data=result_user['response']['user']
user_data
# Out:
# {'bio': 'I thrive on trying new things, visiting exotic places & noshing on delicious foods. Constantly looking for dog friendly spots that my pups will like.',
#  'canonicalUrl': 'https://foursquare.com/paigeknowsfirst',
#  'checkins': {'count': 18304, 'items': []},
#  'contact': {},
#  'firstName': 'Paige',
#  'friends': {'count': 31,
#   'groups': [{'count': 31,
#     'items': [{'bio': '',
#       'contact': {},
#       'firstName': 'Jen',
#       'gender': 'female',
#       'homeCity': 'New York, NY',
#       'id': '48519984',
#       'lastName': 'Pace',
#       'lists': {'groups': [{'count': 2, 'items': [], 'type': 'created'}]},
#       'photo': {'prefix': 'https://igx.4sqi.net/img/user/',
#        'suffix': '/48519984-I3FRIHLO1CXJVKB1.jpg'},
#       'tips': {'count': 6}},
#      {'bio': 'DJ. MC. Self-Proclaimed #GAMECHANGER. Polish #3BlocksFromCompton',
#       'contact': {},
#       'firstName': 'Eva',
#       'gender': 'female',
#       'homeCity': 'Los Angeles, CA',
#       'id': '9876567',
#       'lastName': 'Magazine',
#       'lists': {'groups': [{'count': 14, 'items': [], 'type': 'created'}]},
#       'photo': {'prefix': 'https://igx.4sqi.net/img/user/',
#        'suffix': '/-DPSN5MT5KHHKELDB.png'},
#       'tips': {'count': 36}},
#      {'bio': '',
#       'contact': {},
#       'firstName': 'Meg',
#       'gender': 'female',
#       'homeCity': 'New York, NY',
#       'id': '10754100',
#       'lastName': 'Toth',
#       'lists': {'groups': [{'count': 2, 'items': [], 'type': 'created'}]},
#       'photo': {'prefix': 'https://igx.4sqi.net/img/user/',
#        'suffix': '/10754100-1DAFKBFQX2CV0OOG.jpg'},
#       'tips': {'count': 4}},
#      {'bio': 'There are good ships and there are bad ships, but the best ships, are friendships.',
#       'contact': {},
#       'firstName': 'Brian',
#       'gender': 'male',
#       'homeCity': 'NYC',
#       'id': '305636',
#       'lastName': 'H',
#       'lists': {'groups': [{'count': 11, 'items': [], 'type': 'created'}]},
#       'photo': {'prefix': 'https://igx.4sqi.net/img/user/',
#        'suffix': '/1RSNFSXT4KWAPKYV.jpg'},
#       'superuser': 2,
#       'tips': {'count': 35}},
#      {'bio': '',
#       'contact': {},
#       'firstName': 'Caitlin',
#       'gender': 'female',
#       'homeCity': 'Brooklyn, NY',
#       'id': '2561568',
#       'lastName': 'Tremblay',
#       'lists': {'groups': [{'count': 2, 'items': [], 'type': 'created'}]},
#       'photo': {'prefix': 'https://igx.4sqi.net/img/user/',
#        'suffix': '/2561568-K4OY4CZYIO1OWP2V.jpg'},
#       'tips': {'count': 17}},
#      {'bio': '',
#       'contact': {},
#       'firstName': 'Charlie',
#       'gender': 'male',
#       'homeCity': '',
#       'id': '94687495',
#       'lastName': 'Katz',
#       'lists': {'groups': [{'count': 2, 'items': [], 'type': 'created'}]},
#       'photo': {'prefix': 'https://igx.4sqi.net/img/user/',
#        'suffix': '/94687495-IV13IUV4YJXSZ5LT.jpg'},
#       'tips': {'count': 0}},
#      {'bio': '',
#       'contact': {},
#       'firstName': 'Dana',
#       'gender': 'female',
#       'homeCity': 'Brookfield, CT',
#       'id': '11592659',
#       'lastName': 'Murphy',
#       'lists': {'groups': [{'count': 2, 'items': [], 'type': 'created'}]},
#       'photo': {'prefix': 'https://igx.4sqi.net/img/user/',
#        'suffix': '/3UZXKFP2SEAT53HL.jpg'},
#       'tips': {'count': 3}},
#      {'bio': '',
#       'contact': {},
#       'firstName': 'Jonathan',
#       'gender': 'male',
#       'homeCity': '',
#       'id': '38608670',
#       'lastName': 'Levine',
#       'lists': {'groups': [{'count': 2, 'items': [], 'type': 'created'}]},
#       'photo': {'prefix': 'https://igx.4sqi.net/img/user/',
#        'suffix': '/38608670-LDC2OBIODMIEFSF5.jpg'},
#       'tips': {'count': 0}},
#      {'bio': '',
#       'contact': {},
#       'firstName': 'Joe',
#       'gender': 'male',
#       'homeCity': 'Los Angeles, CA',
#       'id': '6969890',
#       'lastName': 'Rome',
#       'lists': {'groups': [{'count': 2, 'items': [], 'type': 'created'}]},
#       'photo': {'prefix': 'https://igx.4sqi.net/img/user/',
#        'suffix': '/POCA4JWZR5TU3WX2.jpg'},
#       'tips': {'count': 38}},
#      {'bio': '',
#       'contact': {},
#       'firstName': 'Lisa',
#       'gender': 'female',
#       'homeCity': 'New York, New York',
#       'id': '2339403',
#       'lastName': 'Kirshner',
#       'lists': {'groups': [{'count': 4, 'items': [], 'type': 'created'}]},
#       'photo': {'prefix': 'https://igx.4sqi.net/img/user/',
#        'suffix': '/2OVSQ2GBNEBTXHV4.jpg'},
#       'tips': {'count': 4}}],
#     'name': 'Other friends',
#     'type': 'others'}]},
#  'gender': 'female',
#  'homeCity': 'New York, NY',
#  'id': '7835045',
#  'lastName': 'C',
#  'lenses': [],
#  'lists': {'count': 195,
#   'groups': [{'count': 95,
#     'items': [{'canonicalUrl': 'https://foursquare.com/paigeknowsfirst/list/delicious-desserts',
#       'collaborative': False,
#       'createdAt': 1367923355,
#       'description': 'My favorite cakes, cookies and pasties all over the world!',
#       'editable': False,
#       'followers': {'count': 0},
#       'id': '5188da9b498e17ceddc19157',
#       'listItems': {'count': 147},
#       'name': 'Delicious Desserts',
#       'photo': {'createdAt': 1377551917,
#        'height': 612,
#        'id': '521bc62d11d2624bbfbf02a4',
#        'prefix': 'https://igx.4sqi.net/img/general/',
#        'suffix': '/12919849_MUL62ZNcoqt9BInM300EkOkLpzOxZmoo6wCLgmk-Af8.jpg',
#        'user': {'firstName': 'Jamison',
#         'gender': 'male',
#         'id': '12919849',
#         'lastName': 'Ng',
#         'photo': {'prefix': 'https://igx.4sqi.net/img/user/',
#          'suffix': '/3AFESOA2GH1GPV02.jpg'}},
#        'visibility': 'public',
#        'width': 612},
#       'public': True,
#       'updatedAt': 1532631578,
#       'url': '/paigeknowsfirst/list/delicious-desserts'},
#      {'canonicalUrl': 'https://foursquare.com/paigeknowsfirst/list/monofoodal',
#       'collaborative': False,
#       'createdAt': 1397865750,
#       'description': 'Take a Monofoodal Tour of your city - stop at restaurants and food joints which really only specialize in ONE type of food.',
#       'editable': False,
#       'followers': {'count': 0},
#       'id': '5351bd1611d2993499c6ad3d',
#       'listItems': {'count': 31},
#       'name': 'Monofoodal',
#       'photo': {'createdAt': 1392677843,
#        'height': 960,
#        'id': '530293d3498e3a83f3929e1e',
#        'prefix': 'https://igx.4sqi.net/img/general/',
#        'suffix': '/1006688_Hlv2gJut9__CxS7o_FkjCf9iVOAQc-AMlgagQi_vvv0.jpg',
#        'user': {'firstName': 'Mobius',
#         'gender': 'male',
#         'id': '1006688',
#         'lastName': 'Green',
#         'photo': {'prefix': 'https://igx.4sqi.net/img/user/',
#          'suffix': '/JDWO2WIQCYOKNM2Q.jpg'}},
#        'visibility': 'public',
#        'width': 720},
#       'public': True,
#       'updatedAt': 1532631321,
#       'url': '/paigeknowsfirst/list/monofoodal'},
#      {'canonicalUrl': 'https://foursquare.com/paigeknowsfirst/list/date-night-spots',
#       'collaborative': False,
#       'createdAt': 1375646076,
#       'description': '',
#       'editable': False,
#       'followers': {'count': 0},
#       'id': '51feb17c498e47440c577ffa',
#       'listItems': {'count': 72},
#       'name': 'Date Night Spots',
#       'photo': {'createdAt': 1341192716,
#        'height': 720,
#        'id': '4ff0fa0ce4b018b067e520eb',
#        'prefix': 'https://igx.4sqi.net/img/general/',
#        'suffix': '/uoVhDkAiI2B3G080ve6Dc98TIiV0rS6zuiSb52X-Iaw.jpg',
#        'user': {'firstName': 'Aparna',
#         'gender': 'female',
#         'id': '354913',
#         'lastName': 'M',
#         'photo': {'prefix': 'https://igx.4sqi.net/img/user/',
#          'suffix': '/KVWG2VKLNIXJKWTC.jpg'}},
#        'visibility': 'public',
#        'width': 540},
#       'public': True,
#       'updatedAt': 1532559519,
#       'url': '/paigeknowsfirst/list/date-night-spots'}],
#     'type': 'created'},
#    {'count': 98, 'items': [], 'type': 'followed'},
#    {'count': 2,
#     'items': [{'canonicalUrl': 'https://foursquare.com/paigeknowsfirst/list/todos',
#       'collaborative': False,
#       'description': '',
#       'editable': False,
#       'id': '7835045/todos',
#       'listItems': {'count': 231},
#       'name': "Paige's Saved Places",
#       'public': True,
#       'type': 'todos',
#       'url': '/paigeknowsfirst/list/todos'},
#      {'canonicalUrl': 'https://foursquare.com/paigeknowsfirst/list/venuelikes',
#       'collaborative': False,
#       'description': '',
#       'editable': False,
#       'id': '7835045/venuelikes',
#       'listItems': {'count': 0},
#       'name': 'Paige’s Liked Places',
#       'public': True,
#       'type': 'likes',
#       'url': '/paigeknowsfirst/list/venuelikes'}],
#     'type': 'yours'}]},
#  'mayorships': {'count': 0, 'items': []},
#  'photo': {'prefix': 'https://igx.4sqi.net/img/user/',
#   'suffix': '/7835045_vzeT9M7E_W9mOqaLB2Kjg0RdSk9ZaZ3qumWd83vX699ukd2xQKig6s29t8WuzPpeBW54z34H4.jpg'},
#  'photos': {'count': 0, 'items': []},
#  'superuser': 5,
#  'tips': {'count': 1863},
#  'type': 'user'}

# %%
print('First Name: ' + user_data['firstName'])
print('Last Name: ' + user_data['lastName'])
print('Home City: ' + user_data['homeCity'])
print('Count of Tips: '+str(user_data['tips']['count']))
# Out:
# First Name: Paige
# Last Name: C
# Home City: New York, NY
# Count of Tips: 1863

# %% [markdown]
# # Get User's tips
# url = 'https://api.foursquare.com/v2/users/user_id/tips?client_id=CLIENT_ID&client_secret=CLIENT_SECRET&v=VERSION&limit=LIMIT'

# %%
user_id="7835045"
url = f'https://api.foursquare.com/v2/users/{user_id}/tips?client_id={CLIENT_ID}&client_secret={CLIENT_SECRET}&v={VERSION}&limit={LIMIT}'
result=requests.get(url).json()
df=json_normalize(result['response']['tips']['items'])

# %%
df.columns
# Out:
# Index(['agreeCount', 'authorInteractionType', 'canonicalUrl', 'createdAt',
#        'disagreeCount', 'id', 'lastUpvoteTimestamp', 'lastVoteText',
#        'likes.count', 'likes.groups', 'logView', 'photo.createdAt',
#        'photo.height', 'photo.id', 'photo.prefix', 'photo.source.name',
#        'photo.source.url', 'photo.suffix', 'photo.tags', 'photo.visibility',
#        'photo.width', 'photourl', 'text', 'todo.count', 'type',
#        'venue.categories', 'venue.delivery.id',
#        'venue.delivery.provider.icon.name',
#        'venue.delivery.provider.icon.prefix',
#        'venue.delivery.provider.icon.sizes', 'venue.delivery.provider.name',
#        'venue.delivery.url', 'venue.id', 'venue.location.address',
#        'venue.location.cc', 'venue.location.city', 'venue.location.country',
#        'venue.location.crossStreet', 'venue.location.formattedAddress',
#        'venue.location.labeledLatLngs', 'venue.location.lat',
#        'venue.location.lng', 'venue.location.neighborhood',
#        'venue.location.postalCode', 'venue.location.state', 'venue.name',
#        'venue.photos.count', 'venue.photos.groups', 'venue.venuePage.id'],
#       dtype='object')

# %%
pd.set_option('display.max_colwidth', -1)
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id']
tips_filtered = df.loc[:, filtered_columns]

# %%
tips_filtered
# Out:
#                                                                                                                                                                                                       text  \
# 0   Came back for summer restaurant week (after a bad experience during their winter menu). The staff was lovely, food was amazing, and everything went smoothly. They definitely redeemed themselves.
# 1   Delicious soft serve and very unique ice cream flavors. They even have a special cup of whipped cream for dogs! Super friendly staff. I will be back!
# 2   Try the bucket of tots with the mac and cheese on top! I also loved the curly fries with their BBQ sauce.
# 3   What an awesome bar. Go allll the way to the back room. The ambiance is amazing. Beautiful lights and a more quiet back bar. Great place for a date!
# 4   Dining in is a much better experience than ordering out. The food quality is great when you eat there. Not sure why they use different chicken and rice for takeout, but they do. Good sesame chicken!
# 5   Wonderful service and really cheap breakfast specials! $6.55 for eggs, bacon, potatoes, toast, coffee & juice. It might be the best deal on the UES!
# 6   Every Saturday on the Upper East Side! Really fresh produce, baked goods, fish and more. Also a great place to get flower arrangements.
# 7   They finally have a lunch menu! I know they always had happy hour specials, but the $10 lunch specials are great! Choose an appetizer and an entree. Love their tacos and margaritas.
# 8   Awesome addition to the neighborhood! Really good artisan ice cream. It’s a cozy little spot but definitely a good place to come for dessert.
# 9   Limited seating, they permanently got rid of WiFi, and their coffee is overpriced. I’m sorry, what is the appeal of this place?
# 10  Poor service. Food was just ok. Took an hour to get our meal and nobody came to check on us ever. Had to go and find someone to get the bill.
# 11  Came for a drink but ended up staying for the views and the delicious food! Go all the way to the pool level and enjoy a meal or some drinks outside. The fish tacos are great.
# 12  The team here saved my dog’s life. They are hard working, communicative and thorough. I am so appreciative of their dedication to helping sick animals.
# 13  This isn’t a bagel place... it’s a bodega that sells cigarettes next to the bagels (which aren’t even baked on premises!) A disappointing and unnecessary addition to the neighborhood.
# 14  Love their gel pedicures!
# 15  Service could have been better but the food is just as good as the original downtown location. Obsessed with their pita and feta fries!
# 16  Quite possibly the best pancakes I’ve ever had! The chicken and waffles was phenomenal too. Really crowded so be sure to get there early to put your name down.
# 17  Really fun comedy club in the back, part of Comedy Cellar. Enjoyed the show and the food. Great for a group!
# 18  What’s with the thin, tiny tables?? Service is meh.
# 19  Try their flavors of the month, or the Baked by Melissa combo! So good!
# 20  Worst. Sephora. EVER.
# 21  I love their little turf area outside. The shop gets so crowded on weekends (it’s also super tiny) but the coffee was good!
# 22  Great fried rice but their dumplings are ridiculously tiny! They should be twice the size.
# 23  Service is absolutely terrible but the burger is great. Nice place to sit outside!
# 24  A beautiful restaurant with a very fun, eclectic vibe. Be sure to order the vodka flights, the Pierogi, and the Chicken Kiev.
# 25  I was so surprised how easy it was to place an order for such beautiful, extravagant cupcakes! They were not only gorgeous, but delicious! Highly recommend this bakery!
# 26  The food was good and the wait wasn’t terrible, but they really need more variety on their menu. The same items kept coming around on the carts and there wasn’t much to choose from.
# 27  Their bagels are way better than H&H! Good coffee and egg sandwiches too.
# 28  I like this location a lot better than the Times Square one. The food is great but the best item on the menu is their massive strawberry shortcake dessert!
# 29  This place is pretty wild. Their late night brunch party is insane. Food was good. The drinks were not strong at all!
#
#     agreeCount  disagreeCount                        id
# 0   0           0              5b5b645bf96b2c002c95f63b
# 1   0           0              5b5a19f5ccad6b002cebf801
# 2   0           0              5b5a18b9898bdc002cc91ef7
# 3   0           0              5b590075f870fd0039e9fddd
# 4   0           0              5b54fad81ffed7002c22c7ff
# 5   0           0              5b54499290d1ed003927c461
# 6   0           0              5b5447f12d270e001ccb409d
# 7   0           0              5b52544a88a48b0024fddd82
# 8   3           0              5b52537223a2e6002c283642
# 9   0           0              5b4d520ebe7078002c1d3883
# 10  0           0              5b48d6c56a5950002c04d974
# 11  0           0              5b48d6151c0b34002cf671bf
# 12  0           0              5b48d527be7078002c36ee7a
# 13  0           0              5b439951c9f907002ca03f5a
# 14  0           0              5b4398f8b9b37b002ca22fd9
# 15  0           0              5b3bada0fc9e94002c65f09d
# 16  0           0              5b3bad35a795bd002c93501b
# 17  0           0              5b3bac7292e7a9002c82da9b
# 18  0           0              5b3bac237cd14c00447acaf8
# 19  0           0              5b3bab801ffed7002c56b98d
# 20  0           0              5b3bab12b04056002c185ae7
# 21  0           0              5b316cd0efa82a002c946898
# 22  0           0              5b316c9b60d11b002c493adb
# 23  0           0              5b316c4bd69ed0002c2f3c48
# 24  0           0              5b2d45d13e6741002c979be7
# 25  0           0              5b2d451dd69ed0002c686a92
# 26  0           0              5b2a25b0efa82a002c6863e6
# 27  0           0              5b2a2557da5ede002c7e6ad9
# 28  0           0              5b2a242f98fbfc002c162b45
# 29  0           0              5b26373c8ad62e002c1f4f17

# %% [markdown]
# # Get User's friends

# %%
user_friends = json_normalize(user_data['friends']['groups'][0]['items'])
user_friends
# Out:
#                                                                                   bio  \
# 0
# 1  DJ. MC. Self-Proclaimed #GAMECHANGER. Polish #3BlocksFromCompton
# 2
# 3  There are good ships and there are bad ships, but the best ships, are friendships.
# 4
# 5
# 6
# 7
# 8
# 9
#
#   firstName  gender            homeCity        id  lastName  \
# 0  Jen       female  New York, NY        48519984  Pace
# 1  Eva       female  Los Angeles, CA     9876567   Magazine
# 2  Meg       female  New York, NY        10754100  Toth
# 3  Brian     male    NYC                 305636    H
# 4  Caitlin   female  Brooklyn, NY        2561568   Tremblay
# 5  Charlie   male                        94687495  Katz
# 6  Dana      female  Brookfield, CT      11592659  Murphy
# 7  Jonathan  male                        38608670  Levine
# 8  Joe       male    Los Angeles, CA     6969890   Rome
# 9  Lisa      female  New York, New York  2339403   Kirshner
#
#                                       lists.groups  \
# 0  [{'type': 'created', 'count': 2, 'items': []}]
# 1  [{'type': 'created', 'count': 14, 'items': []}]
# 2  [{'type': 'created', 'count': 2, 'items': []}]
# 3  [{'type': 'created', 'count': 11, 'items': []}]
# 4  [{'type': 'created', 'count': 2, 'items': []}]
# 5  [{'type': 'created', 'count': 2, 'items': []}]
# 6  [{'type': 'created', 'count': 2, 'items': []}]
# 7  [{'type': 'created', 'count': 2, 'items': []}]
# 8  [{'type': 'created', 'count': 2, 'items': []}]
# 9  [{'type': 'created', 'count': 4, 'items': []}]
#
#                      photo.prefix                    photo.suffix  superuser  \
# 0  https://igx.4sqi.net/img/user/  /48519984-I3FRIHLO1CXJVKB1.jpg NaN
# 1  https://igx.4sqi.net/img/user/  /-DPSN5MT5KHHKELDB.png         NaN
# 2  https://igx.4sqi.net/img/user/  /10754100-1DAFKBFQX2CV0OOG.jpg NaN
# 3  https://igx.4sqi.net/img/user/  /1RSNFSXT4KWAPKYV.jpg           2.0
# 4  https://igx.4sqi.net/img/user/  /2561568-K4OY4CZYIO1OWP2V.jpg  NaN
# 5  https://igx.4sqi.net/img/user/  /94687495-IV13IUV4YJXSZ5LT.jpg NaN
# 6  https://igx.4sqi.net/img/user/  /3UZXKFP2SEAT53HL.jpg          NaN
# 7  https://igx.4sqi.net/img/user/  /38608670-LDC2OBIODMIEFSF5.jpg NaN
# 8  https://igx.4sqi.net/img/user/  /POCA4JWZR5TU3WX2.jpg          NaN
# 9  https://igx.4sqi.net/img/user/  /2OVSQ2GBNEBTXHV4.jpg          NaN
#
#    tips.count
# 0  6
# 1  36
# 2  4
# 3  35
# 4  17
# 5  0
# 6  3
# 7  0
# 8  38
# 9  4

# %%
user_friends['firstName']
# Out:
# 0    Jen
# 1    Eva
# 2    Meg
# 3    Brian
# 4    Caitlin
# 5    Charlie
# 6    Dana
# 7    Jonathan
# 8    Joe
# 9    Lisa
# Name: firstName, dtype: object

# %% [markdown]
# # Retrieve the User's Profile Image

# %%
user_data['photo']
# Out:
# {'prefix': 'https://igx.4sqi.net/img/user/',
#  'suffix': '/7835045_vzeT9M7E_W9mOqaLB2Kjg0RdSk9ZaZ3qumWd83vX699ukd2xQKig6s29t8WuzPpeBW54z34H4.jpg'}

# %%
Image(url='https://igx.4sqi.net/img/user/300x300/7835045_vzeT9M7E_W9mOqaLB2Kjg0RdSk9ZaZ3qumWd83vX699ukd2xQKig6s29t8WuzPpeBW54z34H4.jpg')
# Out:
# <img src="https://igx.4sqi.net/img/user/300x300/7835045_vzeT9M7E_W9mOqaLB2Kjg0RdSk9ZaZ3qumWd83vX699ukd2xQKig6s29t8WuzPpeBW54z34H4.jpg"/>

# %% [markdown]
# # Explore a location
# https://api.foursquare.com/v2/venues/explore?client_id=CLIENT_ID&client_secret=CLIENT_SECRET&ll=LATITUDE,LONGITUDE&v=VERSION&limit=LIMIT

# %%
latitude = 37.7866329 
longitude = -122.41195210013
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=L0XUK3OF0DEMWCIMYXLNQEDWMM1GIBC43PQCFYYID2XGX4WV&client_secret=FYVOYA1ZZ3YQ320RWOU5XCVD1Y3TA1BCTGIW2OS5ZJTG4CKH&ll=37.7866329,-122.41195210013&v=20180731&radius=500&limit=30'

# %%
results = requests.get(url).json()
len(results['response']['groups'][0]['items'])
'There are {} around The Marker Hotel.'.format(len(results['response']['groups'][0]['items']))
# Out:
# 'There are 30 around The Marker Hotel.'

# %%
items = results['response']['groups'][0]['items']
items[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'reasonName': 'globalInteractionReason',
#     'summary': 'This spot is popular',
#     'type': 'general'}]},
#  'referralId': 'e-0-4a6f3531f964a5209cd51fe3-0',
#  'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'id': '4bf58dd8d48988d175941735',
#     'name': 'Gym / Fitness Center',
#     'pluralName': 'Gyms or Fitness Centers',
#     'primary': True,
#     'shortName': 'Gym / Fitness'}],
#   'id': '4a6f3531f964a5209cd51fe3',
#   'location': {'address': '524 Post St',
#    'cc': 'US',
#    'city': 'San Francisco',
#    'country': 'United States',
#    'crossStreet': 'at Taylor St',
#    'distance': 189,
#    'formattedAddress': ['524 Post St (at Taylor St)',
#     'San Francisco, CA 94102',
#     'United States'],
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 37.788181056861674,
#      'lng': -122.41106656038573}],
#    'lat': 37.788181056861674,
#    'lng': -122.41106656038573,
#    'postalCode': '94102',
#    'state': 'CA'},
#   'name': 'The Olympic Club',
#   'photos': {'count': 0, 'groups': []}}}

# %%
dataframe = json_normalize(items) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                         name             categories  \
# 0                           The Olympic Club   Gym / Fitness Center
# 1                                    Tselogs    Filipino Restaurant
# 2          Ryoko's Japanese Restaurant & Bar       Sushi Restaurant
# 3                           Bourbon & Branch              Speakeasy
# 4   Wilson & Wilson Private Detective Agency              Speakeasy
# 5                            Benjamin Cooper           Cocktail Bar
# 6              American Conservatory Theater                Theater
# 7                     Pearl's Deluxe Burgers           Burger Joint
# 8                                Le Colonial  Vietnamese Restaurant
# 9                  Taylor Street Coffee Shop            Coffee Shop
# 10                              Mensho Tokyo       Ramen Restaurant
# 11                                 Tradition           Cocktail Bar
# 12                                    Bandit           Burger Joint
# 13                 USA Hostels San Francisco                 Hostel
# 14                                       Rye           Cocktail Bar
# 15                                  Lapisara        Thai Restaurant
# 16                                  Cocobang      Korean Restaurant
# 17                              Redwood Room              Hotel Bar
# 18                              farm : table         Breakfast Spot
# 19                                    Curran                Theater
# 20                   Marrakech Magic Theater                Theater
# 21                  Hostelling International                 Hostel
# 22                           Adelaide Hostel                 Hostel
# 23                         Spoke Art Gallery            Art Gallery
# 24                Honey Honey Cafe & Crepery         Breakfast Spot
# 25                                   Sanraku    Japanese Restaurant
# 26                       Liholiho Yacht Club    Hawaiian Restaurant
# 27                               August Hall            Music Venue
# 28                                  Resolute               Wine Bar
# 29        Little Sheep Mongolian Hot Pot 小肥羊      Hotpot Restaurant
#
#                  address  cc           city        country  \
# 0            524 Post St  US  San Francisco  United States
# 1           552 Jones St  US  San Francisco  United States
# 2          619 Taylor St  US  San Francisco  United States
# 3           501 Jones St  US  San Francisco  United States
# 4           501 Jones St  US  San Francisco  United States
# 5           398 Geary St  US  San Francisco  United States
# 6           405 Geary St  US  San Francisco  United States
# 7            708 Post St  US  San Francisco  United States
# 8            20 Cosmo Pl  US  San Francisco  United States
# 9          375 Taylor St  US  San Francisco  United States
# 10          676 Geary St  US  San Francisco  United States
# 11          441 Jones St  US  San Francisco  United States
# 12          683 Geary St  US  San Francisco  United States
# 13           711 Post St  US  San Francisco  United States
# 14          688 Geary St  US  San Francisco  United States
# 15           698 Post St  US  San Francisco  United States
# 16         550 Taylor St  US  San Francisco  United States
# 17          495 Geary St  US  San Francisco  United States
# 18           754 Post St  US  San Francisco  United States
# 19          445 Geary St  US  San Francisco  United States
# 20  419 O’Farrell Street  US  San Francisco  United States
# 21          312 Mason St  US  San Francisco  United States
# 22   5 Isadora Duncan Ln  US  San Francisco  United States
# 23         816 Sutter St  US  San Francisco  United States
# 24           599 Post St  US  San Francisco  United States
# 25         704 Sutter St  US  San Francisco  United States
# 26         871 Sutter St  US  San Francisco  United States
# 27          420 Mason St  US  San Francisco  United States
# 28          678 Geary St  US  San Francisco  United States
# 29          405 Mason St  US  San Francisco  United States
#
#                             crossStreet  distance  \
# 0                          at Taylor St       189
# 1                           at Geary St       104
# 2                           at Cosmo Pl       172
# 3                       at O'Farrell St       135
# 4                          at O'Farrell       116
# 5                              Mason St       203
# 6                              at Mason       166
# 7           btwn Jones & Leavenworth St       185
# 8   from Taylor St.(btwn Post & Sutter)       188
# 9                          at O'Farrell       124
# 10                    at Leavenworth St       205
# 11                         at O'Farrell       158
# 12                                  NaN       226
# 13                             Jones St       183
# 14             btwn Leavenworth & Jones       224
# 15                          at Jones St       172
# 16                           at Post St       116
# 17                            at Taylor        60
# 18             btwn Jones & Leavenworth       217
# 19                             at Mason       121
# 20                                  NaN        75
# 21                   near O'Farrell St.       203
# 22                         at Taylor St        89
# 23                                Jones       274
# 24                        at Taylor St.       134
# 25                            at Taylor       238
# 26          btwn Jones & Leavenworth St       300
# 27                     btw Post & Geary       202
# 28                          Leavenworth       198
# 29                          at Geary St       189
#
#                                      formattedAddress  \
# 0   [524 Post St (at Taylor St), San Francisco, CA...
# 1   [552 Jones St (at Geary St), San Francisco, CA...
# 2   [619 Taylor St (at Cosmo Pl), San Francisco, C...
# 3   [501 Jones St (at O'Farrell St), San Francisco...
# 4   [501 Jones St (at O'Farrell), San Francisco, C...
# 5   [398 Geary St (Mason St), San Francisco, CA 94...
# 6   [405 Geary St (at Mason), San Francisco, CA 94...
# 7   [708 Post St (btwn Jones & Leavenworth St), Sa...
# 8   [20 Cosmo Pl (from Taylor St.(btwn Post & Sutt...
# 9   [375 Taylor St (at O'Farrell), San Francisco, ...
# 10  [676 Geary St (at Leavenworth St), San Francis...
# 11  [441 Jones St (at O'Farrell), San Francisco, C...
# 12  [683 Geary St, San Francisco, CA 94102, United...
# 13  [711 Post St (Jones St), San Francisco, CA 941...
# 14  [688 Geary St (btwn Leavenworth & Jones), San ...
# 15  [698 Post St (at Jones St), San Francisco, CA ...
# 16  [550 Taylor St (at Post St), San Francisco, CA...
# 17  [495 Geary St (at Taylor), San Francisco, CA 9...
# 18  [754 Post St (btwn Jones & Leavenworth), San F...
# 19  [445 Geary St (at Mason), San Francisco, CA 94...
# 20  [419 O’Farrell Street, San Francisco, CA 94102...
# 21  [312 Mason St (near O'Farrell St.), San Franci...
# 22  [5 Isadora Duncan Ln (at Taylor St), San Franc...
# 23  [816 Sutter St (Jones), San Francisco, CA 9410...
# 24  [599 Post St (at Taylor St.), San Francisco, C...
# 25  [704 Sutter St (at Taylor), San Francisco, CA ...
# 26  [871 Sutter St (btwn Jones & Leavenworth St), ...
# 27  [420 Mason St (btw Post & Geary), San Francisc...
# 28  [678 Geary St (Leavenworth), San Francisco, CA...
# 29  [405 Mason St (at Geary St), San Francisco, CA...
#
#                                        labeledLatLngs        lat         lng  \
# 0   [{'label': 'display', 'lat': 37.78818105686167...  37.788181 -122.411067
# 1   [{'label': 'display', 'lat': 37.78647937415373...  37.786479 -122.413128
# 2   [{'label': 'display', 'lat': 37.788183, 'lng':...  37.788183 -122.411882
# 3   [{'label': 'display', 'lat': 37.78582823420628...  37.785828 -122.413115
# 4   [{'label': 'display', 'lat': 37.78596942443605...  37.785969 -122.412969
# 5   [{'label': 'display', 'lat': 37.787396, 'lng':...  37.787396 -122.409847
# 6   [{'label': 'display', 'lat': 37.78696847403834...  37.786968 -122.410103
# 7   [{'label': 'display', 'lat': 37.78764896810783...  37.787649 -122.413620
# 8   [{'label': 'display', 'lat': 37.78828061940812...  37.788281 -122.412450
# 9   [{'label': 'display', 'lat': 37.78568085058454...  37.785681 -122.411216
# 10  [{'label': 'display', 'lat': 37.78655304019694...  37.786553 -122.414289
# 11  [{'label': 'display', 'lat': 37.785484, 'lng':...  37.785484 -122.413007
# 12  [{'label': 'display', 'lat': 37.78655737908927...  37.786557 -122.414526
# 13  [{'label': 'display', 'lat': 37.78730123472428...  37.787301 -122.413853
# 14  [{'label': 'display', 'lat': 37.786556, 'lng':...  37.786556 -122.414502
# 15  [{'label': 'display', 'lat': 37.787727222811, ...  37.787727 -122.413346
# 16  [{'label': 'display', 'lat': 37.78765541111448...  37.787655 -122.411669
# 17                                                NaN  37.786767 -122.411291
# 18  [{'label': 'display', 'lat': 37.78759853713796...  37.787599 -122.414096
# 19  [{'label': 'display', 'lat': 37.78688957862324...  37.786890 -122.410615
# 20  [{'label': 'display', 'lat': 37.78596934229529...  37.785969 -122.411778
# 21  [{'label': 'display', 'lat': 37.78646732281434...  37.786467 -122.409654
# 22  [{'label': 'display', 'lat': 37.78742754194406...  37.787428 -122.412125
# 23  [{'label': 'display', 'lat': 37.78859771046097...  37.788598 -122.413832
# 24  [{'label': 'display', 'lat': 37.78781313171095...  37.787813 -122.411600
# 25  [{'label': 'display', 'lat': 37.78876931963719...  37.788769 -122.412097
# 26  [{'label': 'display', 'lat': 37.78833241767785...  37.788332 -122.414605
# 27  [{'label': 'display', 'lat': 37.78745205121945...  37.787452 -122.409896
# 28  [{'label': 'display', 'lat': 37.78668, 'lng': ...  37.786680 -122.414210
# 29  [{'label': 'display', 'lat': 37.78723751982485...  37.787238 -122.409940
#
#                            neighborhood postalCode state  \
# 0                                   NaN      94102    CA
# 1                                   NaN      94102    CA
# 2                                   NaN      94102    CA
# 3                                   NaN      94102    CA
# 4                                   NaN      94102    CA
# 5                                   NaN      94102    CA
# 6                                   NaN      94102    CA
# 7                                   NaN      94109    CA
# 8                                   NaN      94109    CA
# 9                                   NaN      94102    CA
# 10                                  NaN      94102    CA
# 11                                  NaN      94102    CA
# 12                           Tenderloin      94102    CA
# 13                                  NaN      94109    CA
# 14                                  NaN      94102    CA
# 15                                  NaN      94109    CA
# 16                                  NaN      94102    CA
# 17                                  NaN      94102    CA
# 18                                  NaN      94109    CA
# 19                                  NaN      94102    CA
# 20                                  NaN      94102    CA
# 21                                  NaN      94102    CA
# 22                                  NaN      94102    CA
# 23                                  NaN      94109    CA
# 24                                  NaN      94102    CA
# 25                       Lower Nob Hill      94109    CA
# 26                                  NaN      94109    CA
# 27  Downtown San Francisco-Union Square      94102    CA
# 28                                  NaN      94102    CA
# 29                                  NaN      94102    CA
#
#                           id
# 0   4a6f3531f964a5209cd51fe3
# 1   56a7f7fa498e29aaf707c5d4
# 2   433c8000f964a52043281fe3
# 3   4617e746f964a52051451fe3
# 4   4d7b1c3e7a1c6dcb57d2ca61
# 5   54f132e7498e5d065370a6b1
# 6   4ab6d922f964a520497920e3
# 7   49c6844cf964a52054571fe3
# 8   40dcbc80f964a52085011fe3
# 9   4a671dbaf964a520edc81fe3
# 10  56b4af45498e429dd2223d46
# 11  4fd95f5ee4b0a2110cfd11a8
# 12  59a0d46475eee41c2c7589e3
# 13  4a7da3daf964a52002ef1fe3
# 14  4410b832f964a520c0301fe3
# 15  5a9c4ec9c58ed74fd59216e3
# 16  4a960947f964a520de2520e3
# 17  42911d00f964a52000241fe3
# 18  4b008eadf964a520733f22e3
# 19  4a3467e0f964a520319c1fe3
# 20  50e787c6e4b0c220c4ae5efe
# 21  4b1c0dccf964a520520124e3
# 22  4a6263a7f964a520efc31fe3
# 23  4de82f4a227148fcea2a1997
# 24  49dad117f964a520b65e1fe3
# 25  4a4acc3af964a52033ac1fe3
# 26  54c2a5e4498ee52a438800f7
# 27  5ac7f1a5e97dfb28c5c39e54
# 28  552f3e8c498e944a9e689bb1
# 29  53e4393b498ee0a807b335a3

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco


# add Ecco as a red circle mark
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    popup='The Marker',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(venues_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Explore Trending Venues
#
# Trending venues are the places around the given latitude and longitude those have the highest foot traffic at this moment it gets updated frequently.

# %% [markdown]
# https://api.foursquare.com/v2/venues/trending?client_id=CLIENT_ID&client_secret=CLIENT_SECRET&ll=LATITUDE,LONGITUDE&v=VERSION

# %%
url = 'https://api.foursquare.com/v2/venues/trending?client_id={}&client_secret={}&ll={},{}&v={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION)

# send GET request and get trending venues
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5b6388d7dd5797468445e7dd'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/conventioncenter_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1ff931735',
#       'name': 'Convention Center',
#       'pluralName': 'Convention Centers',
#       'primary': True,
#       'shortName': 'Convention Center'}],
#     'id': '4cc2f44942d1b60cbdc81313',
#     'location': {'address': '747 Howard St',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'country': 'United States',
#      'crossStreet': 'at Moscone Center',
#      'distance': 979,
#      'formattedAddress': ['747 Howard St (at Moscone Center)',
#       'San Francisco, CA 94103',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.78417067388567,
#        'lng': -122.40126161270385}],
#      'lat': 37.78417067388567,
#      'lng': -122.40126161270385,
#      'postalCode': '94103',
#      'state': 'CA'},
#     'name': 'Moscone South'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d16c941735',
#       'name': 'Burger Joint',
#       'pluralName': 'Burger Joints',
#       'primary': True,
#       'shortName': 'Burgers'}],
#     'id': '5b33d4da840fc2002c3a2b12',
#     'location': {'address': '680 Folsom St',
#      'cc': 'US',
#      'city': 'San Francisco',
#      'country': 'United States',
#      'distance': 1207,
#      'formattedAddress': ['680 Folsom St',
#       'San Francisco, CA 94107',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.784284,
#        'lng': -122.398556}],
#      'lat': 37.784284,
#      'lng': -122.398556,
#      'postalCode': '94107',
#      'state': 'CA'},
#     'name': 'Creator'}]}}

# %%
if len(results['response']['venues']) == 0:
    trending_venues_df = 'No trending venues are available at the moment!'
    
else:
    trending_venues = results['response']['venues']
    trending_venues_df = json_normalize(trending_venues)

    # filter columns
    columns_filtered = ['name', 'categories'] + ['location.distance', 'location.city', 'location.postalCode', 'location.state', 'location.country', 'location.lat', 'location.lng']
    trending_venues_df = trending_venues_df.loc[:, columns_filtered]

    # filter the category for each row
    trending_venues_df['categories'] = trending_venues_df.apply(get_category_type, axis=1)
trending_venues_df
# Out:
#             name         categories  location.distance  location.city  \
# 0  Moscone South  Convention Center                979  San Francisco
# 1        Creator       Burger Joint               1207  San Francisco
#
#   location.postalCode location.state location.country  location.lat  \
# 0               94103             CA    United States     37.784171
# 1               94107             CA    United States     37.784284
#
#    location.lng
# 0   -122.401262
# 1   -122.398556

# %%
if len(results['response']['venues']) == 0:
    venues_map = 'Cannot generate visual as no trending venues are available at the moment!'

else:
    venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco


    # add Ecco as a red circle mark
    folium.features.CircleMarker(
        [latitude, longitude],
        radius=10,
        popup='Ecco',
        fill=True,
        color='red',
        fill_color='red',
        fill_opacity=0.6
    ).add_to(venues_map)


    # add the trending venues as blue circle markers
    for lat, lng, label in zip(trending_venues_df['location.lat'], trending_venues_df['location.lng'], trending_venues_df['name']):
        folium.features.CircleMarker(
            [lat, lng],
            radius=5,
            popup=label,
            fill=True,
            color='blue',
            fill_color='blue',
            fill_opacity=0.6
        ).add_to(venues_map)
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
