# %% [markdown]
# # Segmenting and Clustering Neighborhoods in Toronto

# %%
from bs4 import BeautifulSoup
import requests
import csv
import json
import xml
import pandas as pd

# %%
url='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
source = requests.get(url).text

soup = BeautifulSoup(source, 'lxml')#Beautiful Soup to Parse the url page

table=soup.find('table') #Finds the required table area

#List initialization to collect the Postalcodes, Boroughs and Neighborhoods
postalcode=[]
borough=[]
neighborhood=[]

x=table.tbody #Navidation to the body of the table

for tr in x.find_all('tr'): #Iterating through rows and columns
    td=tr.find_all('td')
    for x in td:
        #Exception handling to bypass the errors
        try:
            borough.append(x.span.a.text) #Collecting the Borough name
            postalcode.append(x.p.b.text)    #Collecting the Postalcode
            s=x.text
            if len(s)!=0:
                neighborhood.append(s[s.find("(")+1:s.find(")")]) #Collecting all the substrings between the paranthesis for the neighborhood info
            else:
                neighborhood.append(x.span.a.text) #If there is no neighborhood then fill the value with borough name
                
        except:
            pass

# %%
#Constructing the main dataframe 
main_df=pd.DataFrame({'PostalCode':postalcode,
                 'Borough':borough,
                 'Neighborhood':neighborhood})

# %%
#Fixing the order of the columns in the main dataframe
main_df=main_df[['PostalCode','Borough','Neighborhood']]

# %%
#Visualizing the first few rows of the dataframe
main_df.head(10)
# Out:
#   PostalCode           Borough  \
# 0        M3A        North York
# 1        M4A        North York
# 2        M5A  Downtown Toronto
# 3        M6A        North York
# 4        M7A      Queen's Park
# 5        M9A         Etobicoke
# 6        M1B       Scarborough
# 7        M3B        North York
# 8        M4B         East York
# 9        M5B  Downtown Toronto
#
#                                         Neighborhood
# 0                                          Parkwoods
# 1                                   Victoria Village
# 2                         Regent Park / Harbourfront
# 3                  Lawrence Manor / Lawrence Heights
# 4  \nM7AQueen's Park\n\nOntario Provincial Govern...
# 5                                   Islington Avenue
# 6                                    Malvern / Rouge
# 7                                          Don Mills
# 8                   Parkview Hill / Woodbine Gardens
# 9                           Garden District, Ryerson

# %%
# @hidden_cell
API_key = 'AIzaSyDREpDH6ZMGqPsn0HsZ5xXzbB_92eMzn-M'

# %%
latitude=[]
longitude=[]

for i in main_df['PostalCode']:
    try:
        url ="https://maps.googleapis.com/maps/api/geocode/json?key={}&address={}".format(API_key,'M3A')
        response = requests.get(url).json() # get response
        geographical_data = response['results'][0]['geometry']['location'] # get geographical coordinates
        latitude.append(geographical_data['lat'])
        longitude.append(geographical_data['lng'])
    except:
        pass
main_df['Latitude']=latitude

main_df['Longitude']=longitude
main_df
# Out:
#     PostalCode              Borough  \
# 0          M3A           North York
# 1          M4A           North York
# 2          M5A     Downtown Toronto
# 3          M6A           North York
# 4          M7A         Queen's Park
# 5          M9A            Etobicoke
# 6          M1B          Scarborough
# 7          M3B           North York
# 8          M4B            East York
# 9          M5B     Downtown Toronto
# 10         M6B           North York
# 11         M9B            Etobicoke
# 12         M1C          Scarborough
# 13         M3C           North York
# 14         M4C            East York
# 15         M5C     Downtown Toronto
# 16         M6C                 York
# 17         M9C            Etobicoke
# 18         M1E          Scarborough
# 19         M4E          The Beaches
# 20         M5E     Downtown Toronto
# 21         M6E                 York
# 22         M1G          Scarborough
# 23         M4G            East York
# 24         M5G     Downtown Toronto
# 25         M6G     Downtown Toronto
# 26         M1H          Scarborough
# 27         M2H           North York
# 28         M3H           North York
# 29         M4H            East York
# ..         ...                  ...
# 71         M4R        North Toronto
# 72         M5R            The Annex
# 73         M6R             Parkdale
# 74         M7R          Mississauga
# 75         M9R            Etobicoke
# 76         M1S          Scarborough
# 77         M4S           Davisville
# 78         M5S     Downtown Toronto
# 79         M6S            Runnymede
# 80         M1T          Scarborough
# 81         M4T           Moore Park
# 82         M5T     Downtown Toronto
# 83         M1V          Scarborough
# 84         M4V           Summerhill
# 85         M5V     Downtown Toronto
# 86         M8V            Etobicoke
# 87         M9V            Etobicoke
# 88         M1W          Scarborough
# 89         M4W     Downtown Toronto
# 90         M5W     Downtown Toronto
# 91         M8W            Etobicoke
# 92         M9W            Etobicoke
# 93         M1X          Scarborough
# 94         M4X     Downtown Toronto
# 95         M5X     Downtown Toronto
# 96         M8X            Etobicoke
# 97         M4Y     Downtown Toronto
# 98         M7Y  Business reply mail
# 99         M8Y            Etobicoke
# 100        M8Z            Etobicoke
#
#                                           Neighborhood   Latitude  Longitude
# 0                                            Parkwoods  32.363577 -90.152413
# 1                                     Victoria Village  32.363577 -90.152413
# 2                           Regent Park / Harbourfront  32.363577 -90.152413
# 3                    Lawrence Manor / Lawrence Heights  32.363577 -90.152413
# 4    \nM7AQueen's Park\n\nOntario Provincial Govern...  32.363577 -90.152413
# 5                                     Islington Avenue  32.363577 -90.152413
# 6                                      Malvern / Rouge  32.363577 -90.152413
# 7                                            Don Mills  32.363577 -90.152413
# 8                     Parkview Hill / Woodbine Gardens  32.363577 -90.152413
# 9                             Garden District, Ryerson  32.363577 -90.152413
# 10                                           Glencairn  32.363577 -90.152413
# 11   West Deane Park / Princess Gardens / Martin Gr...  32.363577 -90.152413
# 12            Rouge Hill / Port Union / Highland Creek  32.363577 -90.152413
# 13                                           Don Mills  32.363577 -90.152413
# 14                                    Woodbine Heights  32.363577 -90.152413
# 15                                      St. James Town  32.363577 -90.152413
# 16                                  Humewood-Cedarvale  32.363577 -90.152413
# 17   Eringate / Bloordale Gardens / Old Burnhamthor...  32.363577 -90.152413
# 18                 Guildwood / Morningside / West Hill  32.363577 -90.152413
# 19                                         The Beaches  32.363577 -90.152413
# 20                                         Berczy Park  32.363577 -90.152413
# 21                                 Caledonia-Fairbanks  32.363577 -90.152413
# 22                                              Woburn  32.363577 -90.152413
# 23                                             Leaside  32.363577 -90.152413
# 24                                  Central Bay Street  32.363577 -90.152413
# 25                                            Christie  32.363577 -90.152413
# 26                                           Cedarbrae  32.363577 -90.152413
# 27                                   Hillcrest Village  32.363577 -90.152413
# 28   Bathurst Manor / Wilson Heights / Downsview North  32.363577 -90.152413
# 29                                    Thorncliffe Park  32.363577 -90.152413
# ..                                                 ...        ...        ...
# 71                                  North Toronto West  32.363577 -90.152413
# 72               The Annex / North Midtown / Yorkville  32.363577 -90.152413
# 73                             Parkdale / Roncesvalles  32.363577 -90.152413
# 74                                      Enclave of L4W  32.363577 -90.152413
# 75   Kingsview Village / St. Phillips / Martin Grov...  32.363577 -90.152413
# 76                                           Agincourt  32.363577 -90.152413
# 77                                          Davisville  32.363577 -90.152413
# 78                     University of Toronto / Harbord  32.363577 -90.152413
# 79                                 Runnymede / Swansea  32.363577 -90.152413
# 80           Clarks Corners / Tam O'Shanter / Sullivan  32.363577 -90.152413
# 81                        Moore Park / Summerhill East  32.363577 -90.152413
# 82         Kensington Market / Chinatown / Grange Park  32.363577 -90.152413
# 83   Milliken / Agincourt North / Steeles East / L'...  32.363577 -90.152413
# 84   Summerhill West / Rathnelly / South Hill / For...  32.363577 -90.152413
# 85   CN Tower / King and Spadina / Railway Lands / ...  32.363577 -90.152413
# 86      New Toronto / Mimico South / Humber Bay Shores  32.363577 -90.152413
# 87   South Steeles / Silverstone / Humbergate / Jam...  32.363577 -90.152413
# 88                      Steeles West / L'Amoreaux West  32.363577 -90.152413
# 89                                            Rosedale  32.363577 -90.152413
# 90                                      Enclave of M5E  32.363577 -90.152413
# 91                             Alderwood / Long Branch  32.363577 -90.152413
# 92   Clairville / Humberwood / Woodbine Downs / Wes...  32.363577 -90.152413
# 93                                         Upper Rouge  32.363577 -90.152413
# 94                        St. James Town / Cabbagetown  32.363577 -90.152413
# 95             First Canadian Place / Underground city  32.363577 -90.152413
# 96     The Kingsway / Montgomery Road / Old Mill North  32.363577 -90.152413
# 97                                Church and Wellesley  32.363577 -90.152413
# 98                                      Enclave of M4L  32.363577 -90.152413
# 99   Old Mill South / King's Mill Park / Sunnylea /...  32.363577 -90.152413
# 100  Mimico NW / The Queensway West / South of Bloo...  32.363577 -90.152413
#
# [101 rows x 5 columns]
