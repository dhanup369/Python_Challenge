# %% [markdown]
# #  FourSquare API-NewYork City Neighborhood Analysis with Python and Folium

# %% [markdown]
# Introduction
#
# This notebook explains how to make calls to the Foursquare API for different purposes. This helps to learn how to construct a URL to send a request to the API to search for a specific type of venues, to explore a particular venue, to explore a Foursquare user, to explore a geographical location, and to get trending venues around a location. Also, helps to learn how to use the visualization library, Folium, to visualize the results.
#
# Contents:
#
# 1. Foursquare API Search Function (Search for a specific venue category)
# 2. Explore a Given Venue
# 3. Get the venue's Tips
# 4. Explore a User (Search a Foursquare User)
# 5. Foursquare API Explore Function (Explore a Location)
# 6. Get Trending Venues

# %%
#!conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation


# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

#!conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Folium installed
# Libraries imported.

# %% [markdown]
# # Define Foursquare Credentials and Version

# %%
from config_foursquare import CLIENT_ID,CLIENT_SECRET
CLIENT_ID =CLIENT_ID
CLIENT_SECRET = CLIENT_SECRET 
VERSION="20180731"
LIMIT=30


import warnings #Warning module to filter any future warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## converting the Contrad Hotel's address to its latitude and longitude coordinates.

# %%
address = '102 North End Ave, New York, NY'
geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 40.7149555 -74.0153365

# %% [markdown]
# ## 1. Search for a specific venue category

# %% [markdown]
# https://api.foursquare.com/v2/venues/search?client_id=CLIENT_ID&client_secret=CLIENT_SECRET&ll=LATITUDE,LONGITUDE&v=VERSION&query=QUERY&radius=RADIUS&limit=LIMIT

# %% [markdown]
# Now, let's assume that it is lunch time, and you are craving Italian food. So, let's define a query to search for Italian food that is within 500 metres from the Conrad Hotel.

# %%
search_query = 'Italian'
radius = 500
print(search_query + ' .... OK!')
# Out:
# Italian .... OK!

# %%
#url="http://api.foursquare.com/v2/venues/search?client_id="+CLIENT_ID+"&client_secret="+CLIENT_SECRET+"&v="+str(VERSION)+"&ll="+str(latitude)+","+str(longitude)+"&query="+search_query+"&radius="+str(radius)+"&limit=10"
url=f"http://api.foursquare.com/v2/venues/search?client_id={CLIENT_ID}&client_secret={CLIENT_SECRET}&v={VERSION}&ll={latitude},{longitude}&query={search_query}&radius={radius}&limit=10"
url
# Out:
# 'http://api.foursquare.com/v2/venues/search?client_id=L0XUK3OF0DEMWCIMYXLNQEDWMM1GIBC43PQCFYYID2XGX4WV&client_secret=FYVOYA1ZZ3YQ320RWOU5XCVD1Y3TA1BCTGIW2OS5ZJTG4CKH&v=20180731&ll=40.7149555,-74.0153365&query=Italian&radius=500&limit=10'

# %% [markdown]
# #### Send the GET Request and examine the results

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5b634c44f594df26867f3927'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'primary': True,
#       'shortName': 'Pizza'}],
#     'delivery': {'id': '294544',
#      'provider': {'icon': {'name': '/delivery_provider_seamless_20180129.png',
#        'prefix': 'https://igx.4sqi.net/img/general/cap/',
#        'sizes': [40, 50]},
#       'name': 'seamless'},
#      'url': 'https://www.seamless.com/menu/harrys-italian-pizza-bar-225-murray-st-new-york/294544?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=294544'},
#     'hasPerk': False,
#     'id': '4fa862b3e4b0ebff2f749f06',
#     'location': {'address': '225 Murray St',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 58,
#      'formattedAddress': ['225 Murray St',
#       'New York, NY 10282',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71521779064671,
#        'lng': -74.01473940209351}],
#      'lat': 40.71521779064671,
#      'lng': -74.01473940209351,
#      'postalCode': '10282',
#      'state': 'NY'},
#     'name': "Harry's Italian Pizza Bar",
#     'referralId': 'v-1533234244'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'primary': True,
#       'shortName': 'Food'}],
#     'hasPerk': False,
#     'id': '4f3232e219836c91c7bfde94',
#     'location': {'address': '63 W Broadway',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 446,
#      'formattedAddress': ['63 W Broadway',
#       'New York, NY 10007',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71446,
#        'lng': -74.010086}],
#      'lat': 40.71446,
#      'lng': -74.010086,
#      'postalCode': '10007',
#      'state': 'NY'},
#     'name': 'Conca Cucina Italian Restaurant',
#     'referralId': 'v-1533234244'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'primary': True,
#       'shortName': 'Italian'}],
#     'hasPerk': False,
#     'id': '3fd66200f964a520f4e41ee3',
#     'location': {'address': '124 Chambers St',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'crossStreet': 'btwn Church St & W Broadway',
#      'distance': 549,
#      'formattedAddress': ['124 Chambers St (btwn Church St & W Broadway)',
#       'New York, NY 10007',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71533713859952,
#        'lng': -74.00884766217825}],
#      'lat': 40.71533713859952,
#      'lng': -74.00884766217825,
#      'postalCode': '10007',
#      'state': 'NY'},
#     'name': 'Ecco',
#     'referralId': 'v-1533234244'}]}}

# %%
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                                                                                                                                                                                                                        categories  \
# 0  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'Pizza Place', 'pluralName': 'Pizza Places', 'shortName': 'Pizza', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_', 'suffix': '.png'}, 'primary': True}]
# 1  [{'id': '4d4b7105d754a06374d81259', 'name': 'Food', 'pluralName': 'Food', 'shortName': 'Food', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_', 'suffix': '.png'}, 'primary': True}]
# 2  [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}]
#
#   delivery.id               delivery.provider.icon.name  \
# 0  294544      /delivery_provider_seamless_20180129.png
# 1  NaN         NaN
# 2  NaN         NaN
#
#            delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 0  https://igx.4sqi.net/img/general/cap/  [40, 50]
# 1  NaN                                    NaN
# 2  NaN                                    NaN
#
#   delivery.provider.name  \
# 0  seamless
# 1  NaN
# 2  NaN
#
#                                                                                                                                                                                             delivery.url  \
# 0  https://www.seamless.com/menu/harrys-italian-pizza-bar-225-murray-st-new-york/294544?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=294544
# 1  NaN
# 2  NaN
#
#    hasPerk                        id location.address      ...       \
# 0  False    4fa862b3e4b0ebff2f749f06  225 Murray St        ...
# 1  False    4f3232e219836c91c7bfde94  63 W Broadway        ...
# 2  False    3fd66200f964a520f4e41ee3  124 Chambers St      ...
#
#           location.crossStreet location.distance  \
# 0  NaN                          58
# 1  NaN                          446
# 2  btwn Church St & W Broadway  549
#
#                                                             location.formattedAddress  \
# 0  [225 Murray St, New York, NY 10282, United States]
# 1  [63 W Broadway, New York, NY 10007, United States]
# 2  [124 Chambers St (btwn Church St & W Broadway), New York, NY 10007, United States]
#
#                                                        location.labeledLatLngs  \
# 0  [{'label': 'display', 'lat': 40.71521779064671, 'lng': -74.01473940209351}]
# 1  [{'label': 'display', 'lat': 40.71446, 'lng': -74.010086}]
# 2  [{'label': 'display', 'lat': 40.71533713859952, 'lng': -74.00884766217825}]
#
#    location.lat location.lng location.postalCode  location.state  \
# 0  40.715218    -74.014739    10282               NY
# 1  40.714460    -74.010086    10007               NY
# 2  40.715337    -74.008848    10007               NY
#
#                               name    referralId
# 0  Harry's Italian Pizza Bar        v-1533234244
# 1  Conca Cucina Italian Restaurant  v-1533234244
# 2  Ecco                             v-1533234244
#
# [3 rows x 23 columns]

# %%
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
print(filtered_columns)
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
# ['name', 'categories', 'location.address', 'location.cc', 'location.city', 'location.country', 'location.crossStreet', 'location.distance', 'location.formattedAddress', 'location.labeledLatLngs', 'location.lat', 'location.lng', 'location.postalCode', 'location.state', 'id']
#                               name          categories          address  cc  \
# 0  Harry's Italian Pizza Bar        Pizza Place         225 Murray St    US
# 1  Conca Cucina Italian Restaurant  Food                63 W Broadway    US
# 2  Ecco                             Italian Restaurant  124 Chambers St  US
#
#        city        country                  crossStreet  distance  \
# 0  New York  United States  NaN                          58
# 1  New York  United States  NaN                          446
# 2  New York  United States  btwn Church St & W Broadway  549
#
#                                                                      formattedAddress  \
# 0  [225 Murray St, New York, NY 10282, United States]
# 1  [63 W Broadway, New York, NY 10007, United States]
# 2  [124 Chambers St (btwn Church St & W Broadway), New York, NY 10007, United States]
#
#                                                                 labeledLatLngs  \
# 0  [{'label': 'display', 'lat': 40.71521779064671, 'lng': -74.01473940209351}]
# 1  [{'label': 'display', 'lat': 40.71446, 'lng': -74.010086}]
# 2  [{'label': 'display', 'lat': 40.71533713859952, 'lng': -74.00884766217825}]
#
#          lat        lng postalCode state                        id
# 0  40.715218 -74.014739  10282      NY    4fa862b3e4b0ebff2f749f06
# 1  40.714460 -74.010086  10007      NY    4f3232e219836c91c7bfde94
# 2  40.715337 -74.008848  10007      NY    3fd66200f964a520f4e41ee3

# %%
dataframe_filtered.name
# Out:
# 0    Harry's Italian Pizza Bar
# 1    Conca Cucina Italian Restaurant
# 2    Ecco
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng ,label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 2.Explore a Given Venue
#
# https://api.foursquare.com/v2/venues/VENUE_ID?client_id=CLIENT_ID&client_secret=CLIENT_SECRET&v=VERSION

# %%
url_ven=f"https://api.foursquare.com/v2/venues/4fa862b3e4b0ebff2f749f06?&client_id={CLIENT_ID}&client_secret={CLIENT_SECRET}&v={VERSION}"

# %%
url_ven
# Out:
# 'https://api.foursquare.com/v2/venues/4fa862b3e4b0ebff2f749f06?&client_id=L0XUK3OF0DEMWCIMYXLNQEDWMM1GIBC43PQCFYYID2XGX4WV&client_secret=FYVOYA1ZZ3YQ320RWOU5XCVD1Y3TA1BCTGIW2OS5ZJTG4CKH&v=20180731'

# %%
result_ven=requests.get(url_ven).json()
result_ven
# Out:
# {'meta': {'code': 200, 'requestId': '5b634c46351e3d7b3e03617b'},
#  'response': {'venue': {'allowMenuUrlEdit': True,
#    'attributes': {'groups': [{'count': 1,
#       'items': [{'displayName': 'Price',
#         'displayValue': '$$',
#         'priceTier': 2}],
#       'name': 'Price',
#       'summary': '$$',
#       'type': 'price'},
#      {'count': 7,
#       'items': [{'displayName': 'Credit Cards',
#         'displayValue': 'Yes (incl. American Express)'}],
#       'name': 'Credit Cards',
#       'summary': 'Credit Cards',
#       'type': 'payments'},
#      {'count': 1,
#       'items': [{'displayName': 'Outdoor Seating', 'displayValue': 'Yes'}],
#       'name': 'Outdoor Seating',
#       'summary': 'Outdoor Seating',
#       'type': 'outdoorSeating'},
#      {'count': 8,
#       'items': [{'displayName': 'Brunch', 'displayValue': 'Brunch'},
#        {'displayName': 'Lunch', 'displayValue': 'Lunch'},
#        {'displayName': 'Dinner', 'displayValue': 'Dinner'},
#        {'displayName': 'Happy Hour', 'displayValue': 'Happy Hour'}],
#       'name': 'Menus',
#       'summary': 'Happy Hour, Brunch & more',
#       'type': 'serves'},
#      {'count': 5,
#       'items': [{'displayName': 'Beer', 'displayValue': 'Beer'},
#        {'displayName': 'Wine', 'displayValue': 'Wine'},
#        {'displayName': 'Cocktails', 'displayValue': 'Cocktails'}],
#       'name': 'Drinks',
#       'summary': 'Beer, Wine & Cocktails',
#       'type': 'drinks'},
#      {'count': 5,
#       'items': [{'displayName': 'Delivery', 'displayValue': 'Delivery'}],
#       'name': 'Dining Options',
#       'summary': 'Delivery',
#       'type': 'diningOptions'}]},
#    'beenHere': {'count': 0,
#     'lastCheckinExpiredAt': 0,
#     'marked': False,
#     'unconfirmedCount': 0},
#    'bestPhoto': {'createdAt': 1336776717,
#     'height': 640,
#     'id': '4fad980de4b091b4626c3633',
#     'prefix': 'https://igx.4sqi.net/img/general/',
#     'source': {'name': 'Foursquare for Android',
#      'url': 'https://foursquare.com/download/#/android'},
#     'suffix': '/ya1iQFI7pLjuIJp1PGDKlrZS3OJdHCF7tpILMmjv_2w.jpg',
#     'visibility': 'public',
#     'width': 480},
#    'canonicalUrl': 'https://foursquare.com/v/harrys-italian-pizza-bar/4fa862b3e4b0ebff2f749f06',
#    'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#       'suffix': '.png'},
#      'id': '4bf58dd8d48988d1ca941735',
#      'name': 'Pizza Place',
#      'pluralName': 'Pizza Places',
#      'primary': True,
#      'shortName': 'Pizza'},
#     {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#       'suffix': '.png'},
#      'id': '4bf58dd8d48988d110941735',
#      'name': 'Italian Restaurant',
#      'pluralName': 'Italian Restaurants',
#      'shortName': 'Italian'}],
#    'colors': {'algoVersion': 3,
#     'highlightColor': {'photoId': '4fad980de4b091b4626c3633',
#      'value': -13619152},
#     'highlightTextColor': {'photoId': '4fad980de4b091b4626c3633',
#      'value': -1}},
#    'contact': {'formattedPhone': '(212) 608-1007', 'phone': '2126081007'},
#    'createdAt': 1336435379,
#    'delivery': {'id': '294544',
#     'provider': {'icon': {'name': '/delivery_provider_seamless_20180129.png',
#       'prefix': 'https://igx.4sqi.net/img/general/cap/',
#       'sizes': [40, 50]},
#      'name': 'seamless'},
#     'url': 'https://www.seamless.com/menu/harrys-italian-pizza-bar-225-murray-st-new-york/294544?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=294544'},
#    'dislike': False,
#    'hasMenu': True,
#    'hereNow': {'count': 1,
#     'groups': [{'count': 1,
#       'items': [],
#       'name': 'Other people here',
#       'type': 'others'}],
#     'summary': 'One other person is here'},
#    'hours': {'dayData': [],
#     'isLocalHoliday': False,
#     'isOpen': True,
#     'richStatus': {'entities': [], 'text': 'Open until Midnight'},
#     'status': 'Open until Midnight',
#     'timeframes': [{'days': 'Mon–Wed, Sun',
#       'open': [{'renderedTime': '11:30 AM–11:00 PM'}],
#       'segments': []},
#      {'days': 'Thu–Sat',
#       'includesToday': True,
#       'open': [{'renderedTime': '11:30 AM–Midnight'}],
#       'segments': []}]},
#    'id': '4fa862b3e4b0ebff2f749f06',
#    'inbox': {'count': 0, 'items': []},
#    'likes': {'count': 115,
#     'groups': [{'count': 115, 'items': [], 'type': 'others'}],
#     'summary': '115 Likes'},
#    'listed': {'count': 50,
#     'groups': [{'count': 50,
#       'items': [{'canonicalUrl': 'https://foursquare.com/becca_mcarthur/list/manhattan-haunts',
#         'collaborative': False,
#         'createdAt': 1336094672,
#         'description': '',
#         'editable': False,
#         'followers': {'count': 22},
#         'id': '4fa32fd0e4b04193744746b1',
#         'listItems': {'count': 187,
#          'items': [{'createdAt': 1342934485,
#            'id': 'v4fa862b3e4b0ebff2f749f06'}]},
#         'name': 'Manhattan Haunts',
#         'photo': {'createdAt': 1317849414,
#          'height': 330,
#          'id': '4e8cc9461081e3b3544e12e5',
#          'prefix': 'https://igx.4sqi.net/img/general/',
#          'suffix': '/0NLVU2HC1JF4DXIMKWUFW3QBUT31DC11EFNYYHMJG3NDWAPS.jpg',
#          'user': {'firstName': 'Time Out New York',
#           'gender': 'none',
#           'id': '742542',
#           'photo': {'prefix': 'https://igx.4sqi.net/img/user/',
#            'suffix': '/XXHKCBSQHBORZNSR.jpg'},
#           'type': 'page'},
#          'visibility': 'public',
#          'width': 492},
#         'public': True,
#         'type': 'others',
#         'updatedAt': 1380845377,
#         'url': '/becca_mcarthur/list/manhattan-haunts',
#         'user': {'firstName': 'Becca',
#          'gender': 'female',
#          'id': '24592223',
#          'lastName': 'McArthur',
#          'photo': {'prefix': 'https://igx.4sqi.net/img/user/',
#           'suffix': '/24592223-RAW2UYM0GIB1U40K.jpg'}}},
#        {'canonicalUrl': 'https://foursquare.com/kinosfault/list/usa-nyc-man-fidi',
#         'collaborative': False,
#         'createdAt': 1336836475,
#         'description': 'Where to go for decent eats in the restaurant wasteland of Downtown NYC aka FiDi, along with Tribeca & Battery Park City.',
#         'editable': False,
#         'followers': {'count': 20},
#         'id': '4fae817be4b085f6b2a74d19',
#         'listItems': {'count': 271,
#          'items': [{'createdAt': 1373909433,
#            'id': 'v4fa862b3e4b0ebff2f749f06'}]},
#         'name': 'USA NYC MAN FiDi',
#         'photo': {'createdAt': 1436043666,
#          'height': 960,
#          'id': '55984992498e13ba75e353bb',
#          'prefix': 'https://igx.4sqi.net/img/general/',
#          'suffix': '/12113441_iOa6Uh-Xi8bhj2-gpzkkw8MKiAIs7RmOcz_RM7m8ink.jpg',
#          'user': {'firstName': 'Kino',
#           'gender': 'male',
#           'id': '12113441',
#           'photo': {'prefix': 'https://igx.4sqi.net/img/user/',
#            'suffix': '/12113441-K5HTHFLU2MUCM0CM.jpg'}},
#          'visibility': 'public',
#          'width': 540},
#         'public': True,
#         'type': 'others',
#         'updatedAt': 1528087689,
#         'url': '/kinosfault/list/usa-nyc-man-fidi',
#         'user': {'firstName': 'Kino',
#          'gender': 'male',
#          'id': '12113441',
#          'photo': {'prefix': 'https://igx.4sqi.net/img/user/',
#           'suffix': '/12113441-K5HTHFLU2MUCM0CM.jpg'}}},
#        {'canonicalUrl': 'https://foursquare.com/sweetiewill/list/foodie-love-in-ny--02',
#         'collaborative': False,
#         'createdAt': 1382467210,
#         'description': '',
#         'editable': False,
#         'followers': {'count': 7},
#         'id': '5266c68a498e7c667807fe09',
#         'listItems': {'count': 200,
#          'items': [{'createdAt': 1386809936,
#            'id': 'v4fa862b3e4b0ebff2f749f06'}]},
#         'name': 'Foodie Love in NY - 02',
#         'public': True,
#         'type': 'others',
#         'updatedAt': 1391995585,
#         'url': '/sweetiewill/list/foodie-love-in-ny--02',
#         'user': {'firstName': 'WiLL',
#          'gender': 'male',
#          'id': '547977',
#          'photo': {'prefix': 'https://igx.4sqi.net/img/user/',
#           'suffix': '/-Q5NYGDMFDMOITQRR.jpg'}}},
#        {'canonicalUrl': 'https://foursquare.com/rickr7/list/nyc-resturants',
#         'collaborative': True,
#         'createdAt': 1339944944,
#         'description': '',
#         'editable': False,
#         'followers': {'count': 12},
#         'id': '4fddeff0e4b0e078037ac0d3',
#         'listItems': {'count': 196,
#          'items': [{'createdAt': 1514680908,
#            'id': 't54ed3b13498e857fd7dbb6fc'}]},
#         'name': 'NYC Resturants',
#         'photo': {'createdAt': 1349704979,
#          'height': 800,
#          'id': '5072dd13e4b09145cdf782d1',
#          'prefix': 'https://igx.4sqi.net/img/general/',
#          'suffix': '/208205_fGh2OuAZ9qJ4agbAA5wMVNOSIm9kNUlRtNwj1N-adqg.jpg',
#          'user': {'firstName': 'Thalia',
#           'gender': 'female',
#           'id': '208205',
#           'lastName': 'K',
#           'photo': {'prefix': 'https://igx.4sqi.net/img/user/',
#            'suffix': '/SNOOLCAW2AG04ZKD.jpg'}},
#          'visibility': 'public',
#          'width': 800},
#         'public': True,
#         'type': 'others',
#         'updatedAt': 1531684962,
#         'url': '/rickr7/list/nyc-resturants',
#         'user': {'firstName': 'Richard',
#          'gender': 'male',
#          'id': '21563126',
#          'lastName': 'Revilla',
#          'photo': {'prefix': 'https://igx.4sqi.net/img/user/',
#           'suffix': '/21563126_v05J1KPw_SVj6Ehq9g8B9jeAGjFUMsU5QGl-NZ8inUQ7pKQm5bKplW37EmR7jS2A7GYPBBAtl.jpg'}}}],
#       'name': 'Lists from other people',
#       'type': 'others'}]},
#    'location': {'address': '225 Murray St',
#     'cc': 'US',
#     'city': 'New York',
#     'country': 'United States',
#     'formattedAddress': ['225 Murray St',
#      'New York, NY 10282',
#      'United States'],
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.71521779064671,
#       'lng': -74.01473940209351}],
#     'lat': 40.71521779064671,
#     'lng': -74.01473940209351,
#     'postalCode': '10282',
#     'state': 'NY'},
#    'menu': {'anchor': 'View Menu',
#     'label': 'Menu',
#     'mobileUrl': 'https://foursquare.com/v/4fa862b3e4b0ebff2f749f06/device_menu',
#     'type': 'Menu',
#     'url': 'https://foursquare.com/v/harrys-italian-pizza-bar/4fa862b3e4b0ebff2f749f06/menu'},
#    'name': "Harry's Italian Pizza Bar",
#    'ok': False,
#    'pageUpdates': {'count': 0, 'items': []},
#    'photos': {'count': 141,
#     'groups': [{'count': 141,
#       'items': [{'createdAt': 1336776717,
#         'height': 640,
#         'id': '4fad980de4b091b4626c3633',
#         'prefix': 'https://igx.4sqi.net/img/general/',
#         'source': {'name': 'Foursquare for Android',
#          'url': 'https://foursquare.com/download/#/android'},
#         'suffix': '/ya1iQFI7pLjuIJp1PGDKlrZS3OJdHCF7tpILMmjv_2w.jpg',
#         'user': {'firstName': 'Leony',
#          'gender': 'none',
#          'id': '13676709',
#          'lastName': 'Naciri',
#          'photo': {'prefix': 'https://igx.4sqi.net/img/user/',
#           'suffix': '/T0ANFNGNMCHUDEUE.jpg'}},
#         'visibility': 'public',
#         'width': 480}],
#       'name': 'Venue photos',
#       'type': 'venue'}]},
#    'popular': {'isLocalHoliday': False,
#     'isOpen': False,
#     'timeframes': [{'days': 'Today',
#       'includesToday': True,
#       'open': [{'renderedTime': 'Noon–2:00 PM'},
#        {'renderedTime': '5:00 PM–10:00 PM'}],
#       'segments': []},
#      {'days': 'Fri',
#       'open': [{'renderedTime': 'Noon–3:00 PM'},
#        {'renderedTime': '5:00 PM–11:00 PM'}],
#       'segments': []},
#      {'days': 'Sat',
#       'open': [{'renderedTime': 'Noon–11:00 PM'}],
#       'segments': []},
#      {'days': 'Sun',
#       'open': [{'renderedTime': 'Noon–3:00 PM'},
#        {'renderedTime': '5:00 PM–8:00 PM'}],
#       'segments': []},
#      {'days': 'Mon',
#       'open': [{'renderedTime': 'Noon–2:00 PM'},
#        {'renderedTime': '6:00 PM–8:00 PM'}],
#       'segments': []},
#      {'days': 'Tue–Wed',
#       'open': [{'renderedTime': 'Noon–2:00 PM'},
#        {'renderedTime': '5:00 PM–10:00 PM'}],
#       'segments': []}]},
#    'price': {'currency': '$', 'message': 'Moderate', 'tier': 2},
#    'rating': 7.1,
#    'ratingColor': 'C5DE35',
#    'ratingSignals': 202,
#    'reasons': {'count': 1,
#     'items': [{'reasonName': 'rawLikesReason',
#       'summary': 'Lots of people like this place',
#       'type': 'general'}]},
#    'shortUrl': 'http://4sq.com/JNblHV',
#    'specials': {'count': 0, 'items': []},
#    'stats': {'tipCount': 53},
#    'timeZone': 'America/New_York',
#    'tips': {'count': 53,
#     'groups': [{'count': 53,
#       'items': [{'agreeCount': 4,
#         'canonicalUrl': 'https://foursquare.com/item/53d27909498e0523841340b6',
#         'createdAt': 1406302473,
#         'disagreeCount': 0,
#         'id': '53d27909498e0523841340b6',
#         'lang': 'en',
#         'likes': {'count': 4,
#          'groups': [{'count': 4,
#            'items': [{'firstName': 'P.',
#              'gender': 'male',
#              'id': '369426',
#              'lastName': 'M.',
#              'photo': {'prefix': 'https://igx.4sqi.net/img/user/',
#               'suffix': '/JPQYUWJKUT0H2OO4.jpg'}},
#             {'firstName': 'Diane',
#              'gender': 'female',
#              'id': '87587879',
#              'lastName': 'Danneels',
#              'photo': {'prefix': 'https://igx.4sqi.net/img/user/',
#               'suffix': '/87587879-ESLRSZLQ2CBE2P4W.jpg'}},
#             {'firstName': 'Tim',
#              'gender': 'male',
#              'id': '87591341',
#              'lastName': 'Sheehan',
#              'photo': {'prefix': 'https://igx.4sqi.net/img/user/',
#               'suffix': '/-Z4YK4VKE0JSVXIY1.jpg'}},
#             {'firstName': 'TenantKing.com',
#              'gender': 'none',
#              'id': '87473404',
#              'photo': {'prefix': 'https://igx.4sqi.net/img/user/',
#               'suffix': '/87473404-HI5DTBTK0HX401CA.png'},
#              'type': 'page'}],
#            'type': 'others'}],
#          'summary': '4 likes'},
#         'logView': True,
#         'text': "Harry's Italian Pizza bar is known for it's amazing pizza, but did you know that the brunches here are amazing too? Try the Nutella French toast and we know you'll be sold.",
#         'todo': {'count': 0},
#         'type': 'user',
#         'user': {'firstName': 'TenantKing.com',
#          'gender': 'none',
#          'id': '87473404',
#          'photo': {'prefix': 'https://igx.4sqi.net/img/user/',
#           'suffix': '/87473404-HI5DTBTK0HX401CA.png'},
#          'type': 'page'}}],
#       'name': 'All tips',
#       'type': 'others'}]},
#    'url': 'http://harrysitalian.com',
#    'verified': False}}}

# %%
result_ven['response']['venue'].keys()
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'url', 'price', 'hasMenu', 'likes', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'delivery', 'menu', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'hours', 'popular', 'pageUpdates', 'inbox', 'attributes', 'bestPhoto', 'colors'])

# %% [markdown]
# ### Venue's overall rating:

# %%
result_ven['response']['venue']['rating']
# Out:
# 7.1

# %%
try:
    print(result_ven['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 7.1

# %% [markdown]
# ### Comparing the raitngs of all 3 venues in that neighborhood

# %%
venueid='4f3232e219836c91c7bfde94'
url_ven=f"https://api.foursquare.com/v2/venues/{venueid}?&client_id={CLIENT_ID}&client_secret={CLIENT_SECRET}&v={VERSION}"

# %%
result_ven=requests.get(url_ven).json()
try:
    print(result_ven['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %%
venueid='3fd66200f964a520f4e41ee3'
url_ven=f"https://api.foursquare.com/v2/venues/{venueid}?&client_id={CLIENT_ID}&client_secret={CLIENT_SECRET}&v={VERSION}"

# %%
result_ven=requests.get(url_ven).json()
try:
    print(result_ven['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 7.8

# %% [markdown]
# #### Since this restaurant has a slightly better rating, let's explore it further.

# %% [markdown]
# #### Get the number of tips

# %%
result_ven['response']['venue']['tips']['count']
# Out:
# 15

# %% [markdown]
# ## 3. Get the venue's tips
#
# https://api.foursquare.com/v2/venues/VENUE_ID/tips?client_id=CLIENT_ID&client_secret=CLIENT_SECRET&v=VERSION&limit=LIMIT

# %%
VENUE_ID='3fd66200f964a520f4e41ee3'
url_tips=f"https://api.foursquare.com/v2/venues/{VENUE_ID}/tips?client_id={CLIENT_ID}&client_secret={CLIENT_SECRET}&v={VERSION}&limit={LIMIT}"

# %%
result_tips=requests.get(url_tips).json()

# %%
result_tips['response']['tips']['items'][0]['text']
# Out:
# 'A+ Italian food! Trust me on this: my mom’s side of the family is 100% Italian. I was born and bred to know good pasta when I see it, and Ecco is one of my all-time NYC favorites'

# %%
tips_df=json_normalize(result_tips['response']['tips']['items'][0])

# %%
tips_df
# Out:
#    agreeCount authorInteractionType  \
# 0  2           liked
#
#                                            canonicalUrl   createdAt  \
# 0  https://foursquare.com/item/5ab1cb46c9a517174651d3fe  1521601350
#
#    disagreeCount                        id lang  lastUpvoteTimestamp  \
# 0  0              5ab1cb46c9a517174651d3fe  en   1532734219
#
#          lastVoteText  likes.count  \
# 0  Upvoted 5 days ago  0
#
#                                              ...                                             \
# 0                                            ...
#
#   logView  \
# 0  True
#
#                                                                                                                                                                                  text  \
# 0  A+ Italian food! Trust me on this: my mom’s side of the family is 100% Italian. I was born and bred to know good pasta when I see it, and Ecco is one of my all-time NYC favorites
#
#   todo.count  type user.firstName user.gender    user.id user.lastName  \
# 0  0          user  Nick           male        484542633  El-Tawil
#
#                 user.photo.prefix  \
# 0  https://igx.4sqi.net/img/user/
#
#                                                                           user.photo.suffix
# 0  /484542633_mK2Yum7T_7Tn9fWpndidJsmw2Hof_6T5vJBKCHPLMK5OL-U5ZiJGj51iwBstcpDLYa3Zvhvis.jpg
#
# [1 rows x 21 columns]

# %%
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id', 'user.firstName', 'user.lastName', 'user.gender', 'user.id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display tips
tips_filtered
# Out:
#                                                                                                                                                                                  text  \
# 0  A+ Italian food! Trust me on this: my mom’s side of the family is 100% Italian. I was born and bred to know good pasta when I see it, and Ecco is one of my all-time NYC favorites
#
#    agreeCount  disagreeCount                        id user.firstName  \
# 0  2           0              5ab1cb46c9a517174651d3fe  Nick
#
#   user.lastName user.gender    user.id
# 0  El-Tawil      male        484542633

# %% [markdown]
# ## 4. Search a Foursquare User
#
# https://api.foursquare.com/v2/users/USER_ID?client_id=CLIENT_ID&client_secret=CLIENT_SECRET&v=VERSION

# %%
USER_ID="484542633"
url_user=f"https://api.foursquare.com/v2/users/{USER_ID}?client_id={CLIENT_ID}&client_secret={CLIENT_SECRET}&v={VERSION}"

# %%
result_user=requests.get(url_user).json()
user_data=result_user['response']['user']
result_user['response']['user'].keys()
# Out:
# dict_keys(['id', 'firstName', 'lastName', 'gender', 'canonicalUrl', 'photo', 'friends', 'tips', 'homeCity', 'bio', 'contact', 'photos', 'type', 'mayorships', 'checkins', 'lists', 'lenses'])

# %%
print('First Name: ' + user_data['firstName'])
print('Last Name: ' + user_data['lastName'])
print('Home City: ' + user_data['homeCity'])
print('Count of Tips: '+str(user_data['tips']['count']))
# Out:
# First Name: Nick
# Last Name: El-Tawil
# Home City: New York, NY
# Count of Tips: 249

# %% [markdown]
# ### Get User's tips
# url = 'https://api.foursquare.com/v2/users/user_id/tips?client_id=CLIENT_ID&client_secret=CLIENT_SECRET&v=VERSION&limit=LIMIT'

# %%
user_id="484542633"
url = f'https://api.foursquare.com/v2/users/{user_id}/tips?client_id={CLIENT_ID}&client_secret={CLIENT_SECRET}&v={VERSION}&limit={LIMIT}'
result=requests.get(url).json()
df=json_normalize(result['response']['tips']['items'])

# %%
df.columns
# Out:
# Index(['agreeCount', 'authorInteractionType', 'canonicalUrl', 'createdAt',
#        'disagreeCount', 'id', 'lastUpvoteTimestamp', 'lastVoteText',
#        'likes.count', 'likes.groups', 'logView', 'photo.createdAt',
#        'photo.height', 'photo.id', 'photo.prefix', 'photo.source.name',
#        'photo.source.url', 'photo.suffix', 'photo.tags', 'photo.visibility',
#        'photo.width', 'photourl', 'text', 'todo.count', 'type',
#        'venue.categories', 'venue.delivery.id',
#        'venue.delivery.provider.icon.name',
#        'venue.delivery.provider.icon.prefix',
#        'venue.delivery.provider.icon.sizes', 'venue.delivery.provider.name',
#        'venue.delivery.url', 'venue.id', 'venue.location.address',
#        'venue.location.cc', 'venue.location.city', 'venue.location.country',
#        'venue.location.crossStreet', 'venue.location.formattedAddress',
#        'venue.location.labeledLatLngs', 'venue.location.lat',
#        'venue.location.lng', 'venue.location.neighborhood',
#        'venue.location.postalCode', 'venue.location.state', 'venue.name',
#        'venue.photos.count', 'venue.photos.groups', 'venue.venuePage.id'],
#       dtype='object')

# %%
pd.set_option('display.max_colwidth', -1)
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id']
tips_filtered = df.loc[:, filtered_columns]

# %%
tips_filtered
# Out:
#                                                                                                                                                                                                text  \
# 0   The best! I’m especially fond of the salmon burger, but I’ve had half of the menu and never been disappointed. There’s a reason this place is well known even outside of the Village!
# 1   I used to down a pint of chocolate like it was nothing back when I was bulking. Highly recommended!
# 2   They serve coffee!!!!!!
# 3   I’m a fan. In fact, I’m such a big fan, I want Taim to hire me to be their spokesman. Kind of like the Arabic Jared Fogle - but without the kid stuff.
# 4   The linguine with clams is on point 👌
# 5   Great for a quick, cheap lunch! Shorter lines than Chipotle too👌
# 6   Quick, cheap lunch that tastes good! Way shorter line than Chipotle, too.
# 7   Great for a quick, cheap bite. I stop by when I’m in the neighborhood and don’t have much time to eat.
# 8   You’re not a real New Yorker until you’ve shame-ordered Insomnia Cookies for delivery at 3am
# 9   Good for you yet still tasty! Clean green protein is my go-to after I hit the gym 💪
# 10  Coffee game on point
# 11  This is the dive bar to end all other dive bars. Go here if you like cheap drinks! 🥃
# 12  Burger game strong 💪
# 13  Great burgers & fries! Also, this place is exactly what it’s like when you go to a bar in the Southwest. Source: I’m from Arizona.
# 14  That guy looks familiar...
# 15  Açaí bowl + peanut butter + whey protein = 💪💪💪
# 16  Highly underrated and way less crowded than Central Park!
# 17  Way easier to navigate than the Met proper, plus the Met Breuer focuses on modern art. If I only have a limited amount of time to spend in a museum, I would rather go here than anywhere else!
# 18  Get the açaí bowl with peanut butter after your work out and thank me later 👌
# 19  When you want a burger, this should be the first thing that comes to mind. A+!
# 20  Way less crowded than Central Park! People who live in the neighborhood rave about Carl Schurz Park.
# 21  When college is over but you still want to party, Brother Jimmy’s BBQ is where you should go.
# 22  The best Mexican food in the Murray Hill / Kips Bay area!
# 23  Their bleu cheese burger makes my mouth water just thinking about it!
# 24  Best hummus in the neighborhood!
# 25  Açaí bowls with peanut butter will make you look like Arnold Schwarzenegger 💪
# 26  Best coffee shop in the neighborhood!
# 27  When there’s nice weather, the rooftop at Tonic East is the best place to watch the game. Perfect for March Madness & NBA finals!
# 28  Rib game level 💯
# 29  Joshua Tree is the definition of a “post-college” crowd. This place will bring you right back to your frat house days!
#
#     agreeCount  disagreeCount                        id
# 0   1           0              5aec594b1f7440002c138612
# 1   1           0              5accc9f66fa81f196724807b
# 2   1           0              5accc98c0313204c9d7ec157
# 3   1           0              5accbf033abcaf09a24612a0
# 4   1           0              5accbe3a911fc423730f3ed3
# 5   1           0              5acbecb86fa81f1967e019b0
# 6   1           0              5acbec70a0215b732e264fe8
# 7   1           0              5acbec0c6fa81f1967dfeba3
# 8   1           0              5acbbd4eb1538e45373b07f5
# 9   1           0              5acbbcda01235808d5d6dc75
# 10  1           0              5acbbb1501235808d5d6525e
# 11  1           0              5ab576abea1e444f2abb051e
# 12  1           0              5ab575fb6bdee65f759da8c1
# 13  2           0              5ab5575d73fe2516ad8f363b
# 14  1           0              5ab5299635f98312029a53b7
# 15  1           0              5ab42db53c858d64af2688a4
# 16  1           0              5ab42c396f706a29f53ad1a8
# 17  1           0              5ab42b987dc9e17930e5ff5b
# 18  1           0              5ab42aca2a7ab6333652b266
# 19  1           0              5ab42a28da5e5617d18e3a6a
# 20  1           0              5ab429db1ffe971b060083f5
# 21  1           0              5ab3f5a30d8a0f3140ecbb1d
# 22  1           0              5ab3f53f8496ca57542d5549
# 23  1           0              5ab3f50e7dc9e17930d4d4ec
# 24  1           0              5ab3f4b8da2e00604ca5a97d
# 25  1           0              5ab3f466838e5939e6b95544
# 26  1           0              5ab3f428da5e5617d17d1475
# 27  1           0              5ab3f3fedd70c572de886c9d
# 28  1           0              5ab3f372da2e00604ca53924
# 29  1           0              5ab3f3474c954c7a779f3dca

# %% [markdown]
# ### Let's get the venue for the tip with the greatest number of agree counts

# %%
tip_id = '5ab5575d73fe2516ad8f363b' # tip id

# define URL
url = 'http://api.foursquare.com/v2/tips/{}?client_id={}&client_secret={}&v={}'.format(tip_id, CLIENT_ID, CLIENT_SECRET, VERSION)

# send GET Request and examine results
result = requests.get(url).json()
print(result['response']['tip']['venue']['name'])
print(result['response']['tip']['venue']['location'])
# Out:
# Cowgirl
# {'address': '519 Hudson St', 'crossStreet': 'at W 10th St', 'lat': 40.73375031678678, 'lng': -74.00628236760791, 'labeledLatLngs': [{'label': 'display', 'lat': 40.73375031678678, 'lng': -74.00628236760791}], 'postalCode': '10014', 'cc': 'US', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['519 Hudson St (at W 10th St)', 'New York, NY 10014', 'United States']}

# %% [markdown]
# ### Get User's friends

# %%
user_friends = json_normalize(user_data['friends']['groups'][0]['items'])
user_friends
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# This User has no friends!

# %% [markdown]
# ### Retrieve the User's Profile Image

# %%
user_data['photo']
# Out:
# {'prefix': 'https://igx.4sqi.net/img/user/',
#  'suffix': '/484542633_mK2Yum7T_7Tn9fWpndidJsmw2Hof_6T5vJBKCHPLMK5OL-U5ZiJGj51iwBstcpDLYa3Zvhvis.jpg'}

# %%
# 1. grab prefix of photo
# 2. grab suffix of photo
# 3. concatenate them using the image size  
Image(url='https://igx.4sqi.net/img/user/200x200/484542633_mK2Yum7T_7Tn9fWpndidJsmw2Hof_6T5vJBKCHPLMK5OL-U5ZiJGj51iwBstcpDLYa3Zvhvis.jpg')
# Out:
# <img src="https://igx.4sqi.net/img/user/200x200/484542633_mK2Yum7T_7Tn9fWpndidJsmw2Hof_6T5vJBKCHPLMK5OL-U5ZiJGj51iwBstcpDLYa3Zvhvis.jpg"/>

# %% [markdown]
# # 5. Explore a location

# %% [markdown]
# https://api.foursquare.com/v2/venues/explore?client_id=CLIENT_ID&client_secret=CLIENT_SECRET&ll=LATITUDE,LONGITUDE&v=VERSION&limit=LIMIT

# %% [markdown]
# So, you just finished your gourmet dish at Ecco, and are just curious about the popular spots around the restaurant. In order to explore the area, let's start by getting the latitude and longitude values of Ecco Restaurant.

# %%
latitude = 40.715337
longitude = -74.008848
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=L0XUK3OF0DEMWCIMYXLNQEDWMM1GIBC43PQCFYYID2XGX4WV&client_secret=FYVOYA1ZZ3YQ320RWOU5XCVD1Y3TA1BCTGIW2OS5ZJTG4CKH&ll=40.715337,-74.008848&v=20180731&radius=500&limit=30'

# %%
results = requests.get(url).json()
'There are {} around Ecco restaurant.'.format(len(results['response']['groups'][0]['items']))
# Out:
# 'There are 30 around Ecco restaurant.'

# %%
items = results['response']['groups'][0]['items']
items[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'reasonName': 'globalInteractionReason',
#     'summary': 'This spot is popular',
#     'type': 'general'}]},
#  'referralId': 'e-0-4af5d65ff964a52091fd21e3-0',
#  'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#      'suffix': '.png'},
#     'id': '4bf58dd8d48988d1f8941735',
#     'name': 'Furniture / Home Store',
#     'pluralName': 'Furniture / Home Stores',
#     'primary': True,
#     'shortName': 'Furniture / Home'}],
#   'id': '4af5d65ff964a52091fd21e3',
#   'location': {'address': '57 Warren St',
#    'cc': 'US',
#    'city': 'New York',
#    'country': 'United States',
#    'crossStreet': 'Church St',
#    'distance': 73,
#    'formattedAddress': ['57 Warren St (Church St)',
#     'New York, NY 10007',
#     'United States'],
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.71482437714839,
#      'lng': -74.00940425461492}],
#    'lat': 40.71482437714839,
#    'lng': -74.00940425461492,
#    'neighborhood': 'Tribeca',
#    'postalCode': '10007',
#    'state': 'NY'},
#   'name': 'Korin',
#   'photos': {'count': 0, 'groups': []},
#   'venuePage': {'id': '33104775'}}}

# %%
dataframe = json_normalize(items) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                              name                     categories  \
# 0   Korin                          Furniture / Home Store
# 1   Takahachi Bakery               Bakery
# 2   Chambers Street Wines          Wine Shop
# 3   Takahachi                      Sushi Restaurant
# 4   Juice Press                    Vegetarian / Vegan Restaurant
# 5   Nish Nūsh                      Falafel Restaurant
# 6   Mulberry & Vine                Café
# 7   Equinox Tribeca                Gym / Fitness Center
# 8   Ten Over Ten                   Nail Salon
# 9   Weather Up                     Cocktail Bar
# 10  Little Park                    American Restaurant
# 11  The Odeon                      French Restaurant
# 12  Blaue Gans                     German Restaurant
# 13  Tiny's and the Bar Upstairs    American Restaurant
# 14  Restaurant Marc Forgione       New American Restaurant
# 15  Philip Williams Posters        Antique Shop
# 16  The Mysterious Bookshop        Bookstore
# 17  Exceed Physical Culture        Gym / Fitness Center
# 18  Kula Yoga Project              Yoga Studio
# 19  Khe-Yo                         Restaurant
# 20  Ward III                       Cocktail Bar
# 21  Kaffe 1668                     Coffee Shop
# 22  Heyday                         Spa
# 23  Zucker's Bagels & Smoked Fish  Bagel Shop
# 24  Racines                        French Restaurant
# 25  Sushi of Gari Tribeca          Sushi Restaurant
# 26  Sophie's Cuban Cuisine         Cuban Restaurant
# 27  Frankly Wines                  Wine Shop
# 28  Brushstroke                    Japanese Restaurant
# 29  Tribeca Greenmarket            Farmers Market
#
#              address  cc      city        country  \
# 0   57 Warren St      US  New York  United States
# 1   25 Murray St      US  New York  United States
# 2   148 Chambers St   US  New York  United States
# 3   145 Duane St      US  New York  United States
# 4   83 Murray St      US  New York  United States
# 5   88 Reade St       US  New York  United States
# 6   73 Warren St      US  New York  United States
# 7   54 Murray Street  US  New York  United States
# 8   112 Reade St      US  New York  United States
# 9   159 Duane St      US  New York  United States
# 10  85 W Broadway     US  New York  United States
# 11  145 W Broadway    US  New York  United States
# 12  139 Duane St      US  New York  United States
# 13  135 W Broadway    US  New York  United States
# 14  134 Reade St      US  New York  United States
# 15  122 Chambers St   US  New York  United States
# 16  58 Warren St      US  New York  United States
# 17  97 Reade St       US  New York  United States
# 18  28 Warren St      US  New York  United States
# 19  157 Duane St      US  New York  United States
# 20  111 Reade St      US  New York  United States
# 21  275 Greenwich St  US  New York  United States
# 22  92 Reade St       US  New York  United States
# 23  146 Chambers St   US  New York  United States
# 24  94 Chambers St    US  New York  United States
# 25  130 W Broadway    US  New York  United States
# 26  96 Chambers St    US  New York  United States
# 27  66 W Broadway     US  New York  United States
# 28  30 Hudson St      US  New York  United States
# 29  Greenwich St      US  New York  United States
#
#                         crossStreet  distance  \
# 0   Church St                        73
# 1   at Church St                     179
# 2   btwn West Broadway & Hudson St   88
# 3   btwn W Broadway & Church St      146
# 4   btwn Greenwich St & W Broadway   202
# 5   at Church St                     97
# 6   btwn W Broadway & Greenwich St   117
# 7   at W Broadway                    159
# 8   NaN                              68
# 9   btwn Hudson St. & W Broadway     157
# 10  at Chambers St                   29
# 11  at Thomas St                     195
# 12  at W Broadway                    144
# 13  between Duane St & Thomas St     170
# 14  btwn Hudson and Greenwich St     133
# 15  NaN                              8
# 16  at W Broadway                    71
# 17  bet W Broadway & Church St       79
# 18  Church St                        127
# 19  btwn Hudson St & W Broadway      159
# 20  btwn W Broadway & Church St      64
# 21  at Murray St                     216
# 22  NaN                              86
# 23  btwn W. Broadway & Greenwich St  88
# 24  NaN                              125
# 25  Duane St.                        155
# 26  NaN                              116
# 27  Murray & Warren                  138
# 28  at Duane St                      146
# 29  btw Chambers St & Duane St       236
#
#                                                                           formattedAddress  \
# 0   [57 Warren St (Church St), New York, NY 10007, United States]
# 1   [25 Murray St (at Church St), New York, NY 10007, United States]
# 2   [148 Chambers St (btwn West Broadway & Hudson St), New York, NY 10007, United States]
# 3   [145 Duane St (btwn W Broadway & Church St), New York, NY 10013, United States]
# 4   [83 Murray St (btwn Greenwich St & W Broadway), New York, NY 10007, United States]
# 5   [88 Reade St (at Church St), New York, NY 10013, United States]
# 6   [73 Warren St (btwn W Broadway & Greenwich St), New York, NY 10007, United States]
# 7   [54 Murray Street (at W Broadway), New York, NY 10007, United States]
# 8   [112 Reade St, New York, NY 10013, United States]
# 9   [159 Duane St (btwn Hudson St. & W Broadway), New York, NY 10013, United States]
# 10  [85 W Broadway (at Chambers St), New York, NY 10007, United States]
# 11  [145 W Broadway (at Thomas St), New York, NY 10013, United States]
# 12  [139 Duane St (at W Broadway), New York, NY 10013, United States]
# 13  [135 W Broadway (between Duane St & Thomas St), New York, NY 10013, United States]
# 14  [134 Reade St (btwn Hudson and Greenwich St), New York, NY 10013, United States]
# 15  [122 Chambers St, New York, NY 10007, United States]
# 16  [58 Warren St (at W Broadway), New York, NY 10007, United States]
# 17  [97 Reade St (bet W Broadway & Church St), New York, NY 10013, United States]
# 18  [28 Warren St (Church St), New York, NY 10007, United States]
# 19  [157 Duane St (btwn Hudson St & W Broadway), New York, NY 10013, United States]
# 20  [111 Reade St (btwn W Broadway & Church St), New York, NY 10013, United States]
# 21  [275 Greenwich St (at Murray St), New York, NY 10007, United States]
# 22  [92 Reade St, New York, NY 10013, United States]
# 23  [146 Chambers St (btwn W. Broadway & Greenwich St), New York, NY 10007, United States]
# 24  [94 Chambers St, New York, NY 10007, United States]
# 25  [130 W Broadway (Duane St.), New York, NY 10013, United States]
# 26  [96 Chambers St, New York, NY 10007, United States]
# 27  [66 W Broadway (Murray & Warren), New York, NY 10007, United States]
# 28  [30 Hudson St (at Duane St), New York, NY 10013, United States]
# 29  [Greenwich St (btw Chambers St & Duane St), New York, NY 10013, United States]
#
#                                                                   labeledLatLngs  \
# 0   [{'label': 'display', 'lat': 40.71482437714839, 'lng': -74.00940425461492}]
# 1   [{'label': 'display', 'lat': 40.71372322632139, 'lng': -74.00873266967818}]
# 2   [{'label': 'display', 'lat': 40.715773063928374, 'lng': -74.00971823312332}]
# 3   [{'label': 'display', 'lat': 40.71652647412374, 'lng': -74.00810108466207}]
# 4   [{'label': 'display', 'lat': 40.71478769908051, 'lng': -74.0111317502157}]
# 5   [{'label': 'display', 'lat': 40.71553710116416, 'lng': -74.00772452925565}]
# 6   [{'label': 'display', 'lat': 40.71517693966315, 'lng': -74.01022747778285}]
# 7   [{'label': 'display', 'lat': 40.714057, 'lng': -74.009694}]
# 8   [{'label': 'display', 'lat': 40.71594125566931, 'lng': -74.00872053564494}]
# 9   [{'label': 'display', 'lat': 40.71674084163369, 'lng': -74.0086664438893}]
# 10  [{'label': 'display', 'lat': 40.715486585249735, 'lng': -74.00913313510836}]
# 11  [{'label': 'display', 'lat': 40.71700358931347, 'lng': -74.00810144732247}]
# 12  [{'label': 'display', 'lat': 40.716368276464614, 'lng': -74.0078138365051}]
# 13  [{'label': 'display', 'lat': 40.71679304855808, 'lng': -74.00821998878457}]
# 14  [{'label': 'display', 'lat': 40.71637984317071, 'lng': -74.00962933453428}]
# 15  [{'label': 'display', 'lat': 40.71528423132827, 'lng': -74.00878093952018}]
# 16  [{'label': 'display', 'lat': 40.71490950153982, 'lng': -74.00948027011903}]
# 17  [{'label': 'display', 'lat': 40.7156286200256, 'lng': -74.0079922583853}]
# 18  [{'label': 'display', 'lat': 40.714342290158086, 'lng': -74.00809356840004}]
# 19  [{'label': 'display', 'lat': 40.716752816876635, 'lng': -74.00858376295221}]
# 20  [{'label': 'display', 'lat': 40.715879529594766, 'lng': -74.00859494861464}]
# 21  NaN
# 22  [{'label': 'display', 'lat': 40.715598486687675, 'lng': -74.00788227511288}]
# 23  [{'label': 'display', 'lat': 40.71558, 'lng': -74.00985}]
# 24  [{'label': 'display', 'lat': 40.714754151461236, 'lng': -74.0075806002039}]
# 25  [{'label': 'display', 'lat': 40.71668439227822, 'lng': -74.00834342869238}]
# 26  [{'label': 'display', 'lat': 40.71480295894467, 'lng': -74.00765642063459}]
# 27  [{'label': 'display', 'lat': 40.71447694276293, 'lng': -74.0100388662148}]
# 28  [{'label': 'display', 'lat': 40.71664315915803, 'lng': -74.00909437284267}]
# 29  [{'label': 'display', 'lat': 40.716802033574126, 'lng': -74.01087999343872}]
#
#           lat        lng neighborhood postalCode state  \
# 0   40.714824 -74.009404  Tribeca      10007      NY
# 1   40.713723 -74.008733  NaN          10007      NY
# 2   40.715773 -74.009718  NaN          10007      NY
# 3   40.716526 -74.008101  NaN          10013      NY
# 4   40.714788 -74.011132  NaN          10007      NY
# 5   40.715537 -74.007725  NaN          10013      NY
# 6   40.715177 -74.010227  NaN          10007      NY
# 7   40.714057 -74.009694  NaN          10007      NY
# 8   40.715941 -74.008721  NaN          10013      NY
# 9   40.716741 -74.008666  NaN          10013      NY
# 10  40.715487 -74.009133  NaN          10007      NY
# 11  40.717004 -74.008101  NaN          10013      NY
# 12  40.716368 -74.007814  NaN          10013      NY
# 13  40.716793 -74.008220  NaN          10013      NY
# 14  40.716380 -74.009629  NaN          10013      NY
# 15  40.715284 -74.008781  NaN          10007      NY
# 16  40.714910 -74.009480  NaN          10007      NY
# 17  40.715629 -74.007992  Tribeca      10013      NY
# 18  40.714342 -74.008094  NaN          10007      NY
# 19  40.716753 -74.008584  NaN          10013      NY
# 20  40.715880 -74.008595  NaN          10013      NY
# 21  40.715202 -74.011412  NaN          10007      NY
# 22  40.715598 -74.007882  NaN          10013      NY
# 23  40.715580 -74.009850  NaN          10007      NY
# 24  40.714754 -74.007581  NaN          10007      NY
# 25  40.716684 -74.008343  NaN          10013      NY
# 26  40.714803 -74.007656  NaN          10007      NY
# 27  40.714477 -74.010039  NaN          10007      NY
# 28  40.716643 -74.009094  NaN          10013      NY
# 29  40.716802 -74.010880  NaN          10013      NY
#
#                           id
# 0   4af5d65ff964a52091fd21e3
# 1   4c154c9a77cea593c401d260
# 2   4adcf23cf964a520cc6221e3
# 3   4a8f2f39f964a520471420e3
# 4   54148bc6498ea7bb8c05b70a
# 5   50ba9119e4b071a4bae6dc10
# 6   5171b5cc011cef9833bbb787
# 7   4a6e331af964a52031d41fe3
# 8   4ce2a27cd58c60fc0fa1a76f
# 9   4cd89eeb6e8b5941660c64d2
# 10  545c0436498e798e22ce4b2a
# 11  3fd66200f964a52083e61ee3
# 12  45633154f964a520a53d1fe3
# 13  4dadcb124df0522cc5622202
# 14  48510cf9f964a520a5501fe3
# 15  4b747291f964a52042dd2de3
# 16  4b6469d3f964a52037b12ae3
# 17  53910ac3498e57a5dc0eb160
# 18  4ad79413f964a520610c21e3
# 19  51df85c9498edb5ea3ad2e2a
# 20  4a411ea5f964a520cba41fe3
# 21  49ccd495f964a52091591fe3
# 22  57ad129c498e05b086594d72
# 23  4a4baaf8f964a52091ac1fe3
# 24  534c9d7b498e1bdd443a40e1
# 25  50597c5ce4b05ea41644ac74
# 26  4b311e89f964a520890025e3
# 27  4a7f140cf964a520b4f21fe3
# 28  4d9235c97b5ea1430fbdacb8
# 29  4a8c4baef964a520960d20e3

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco


# add Ecco as a red circle mark
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    popup='Ecco',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(venues_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 6. Explore Trending Venues

# %% [markdown]
# https://api.foursquare.com/v2/venues/trending?client_id=CLIENT_ID&client_secret=CLIENT_SECRET&ll=LATITUDE,LONGITUDE&v=VERSION

# %% [markdown]
# Now, instead of simply exploring the area around Ecco, you are interested in knowing the venues that are trending at the time you are done with your lunch, meaning the places with the highest foot traffic. So let's do that and get the trending venues around Ecco.

# %%
url = 'https://api.foursquare.com/v2/venues/trending?client_id={}&client_secret={}&ll={},{}&v={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION)

# send GET request and get trending venues
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5b634c534c1f677ad6e0f335'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/salad_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1bd941735',
#       'name': 'Salad Place',
#       'pluralName': 'Salad Places',
#       'primary': True,
#       'shortName': 'Salad'}],
#     'id': '5484890c498e985cf4e3c076',
#     'location': {'address': '100 Kenmare St',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'crossStreet': 'btwn Cleveland & Mulberry St',
#      'distance': 1185,
#      'formattedAddress': ['100 Kenmare St (btwn Cleveland & Mulberry St)',
#       'New York, NY 10012',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7211844,
#        'lng': -73.9971105}],
#      'lat': 40.7211844,
#      'lng': -73.9971105,
#      'postalCode': '10012',
#      'state': 'NY'},
#     'name': 'sweetgreen'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/salad_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1bd941735',
#       'name': 'Salad Place',
#       'pluralName': 'Salad Places',
#       'primary': True,
#       'shortName': 'Salad'}],
#     'id': '577c4a4a498e2c214c8f57e1',
#     'location': {'address': '67 Wall St',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 1086,
#      'formattedAddress': ['67 Wall St', 'New York, NY 10005', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.705586,
#        'lng': -74.008382}],
#      'lat': 40.705586,
#      'lng': -74.008382,
#      'postalCode': '10005',
#      'state': 'NY'},
#     'name': 'sweetgreen'}]}}

# %%
#Check if any venues are trending at this time
if len(results['response']['venues']) == 0:
    trending_venues_df = 'No trending venues are available at the moment!'
    
else:
    trending_venues = results['response']['venues']
    trending_venues_df = json_normalize(trending_venues)

    # filter columns
    columns_filtered = ['name', 'categories'] + ['location.distance', 'location.city', 'location.postalCode', 'location.state', 'location.country', 'location.lat', 'location.lng']
    trending_venues_df = trending_venues_df.loc[:, columns_filtered]

    # filter the category for each row
    trending_venues_df['categories'] = trending_venues_df.apply(get_category_type, axis=1)
trending_venues_df
# Out:
#          name   categories  location.distance location.city  \
# 0  sweetgreen  Salad Place  1185               New York
# 1  sweetgreen  Salad Place  1086               New York
#
#   location.postalCode location.state location.country  location.lat  \
# 0  10012               NY             United States    40.721184
# 1  10005               NY             United States    40.705586
#
#    location.lng
# 0 -73.997111
# 1 -74.008382

# %%
if len(results['response']['venues']) == 0:
    venues_map = 'Cannot generate visual as no trending venues are available at the moment!'

else:
    venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco


    # add Ecco as a red circle mark
    folium.features.CircleMarker(
        [latitude, longitude],
        radius=10,
        popup='Ecco',
        fill=True,
        color='red',
        fill_color='red',
        fill_opacity=0.6
    ).add_to(venues_map)


    # add the trending venues as blue circle markers
    for lat, lng, label in zip(trending_venues_df['location.lat'], trending_venues_df['location.lng'], trending_venues_df['name']):
        folium.features.CircleMarker(
            [lat, lng],
            radius=5,
            popup=label,
            fill=True,
            color='blue',
            fill_color='blue',
            fill_opacity=0.6
        ).add_to(venues_map)
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
